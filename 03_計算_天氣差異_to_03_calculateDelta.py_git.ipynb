# %%
# -*- coding: utf-8 -*-

# %% [markdown]
# Reference:
#  1. pyhton print flush。想弄單行輸出
#   +  http://www.revotu.com/python3-print-function-keyword-arguments.html
#   + http://www.revotu.com/how-to-flush-output-of-python-print.html
#   + https://stackoverflow.com/questions/5598181/python-multiple-prints-on-the-same-line

# %% [markdown]
# 輸出設計

# %% [markdown]
# {'2011': {'第001號': {'date': '01-02', 'location': '宜蘭縣', 'strength': '3.9'},
#   '第002號': {"Precp_delta":int,"Temperature_delta":int,"RH_delta":int,"StnPres_delta":int,多少符合},
#          },
# }

# %%
import json

# %% [markdown]
# 紀錄

# %%
deltaDict = dict()

# %% [markdown]
# 全域變數 - 檔案名稱

# %%
specificWeatherDataJSON = "SpecificWeatherData.json" #天氣資料儲存位置
earthquakeDataJSON = "earthquakeData.json" #地震資訊

# %%
dayInterval = 3

# %%
gateDict = {"Precp_gate":10, #降水量 
"Temperature_gate" : 3, #溫度
"RH_gate" : 5,
"StnPres_gate" : 50, #氣壓
           }

# %%
needDataList = ["ObsTime", 'Temperature', 'RH', "Precp", "StnPres"]

# %% [markdown]
# 讀取檔案

# %%
with open(specificWeatherDataJSON, 'r') as inputfile:
    specificWeatherDataDict =  json.load(inputfile)
with open(earthquakeDataJSON, 'r') as inputfile:
    earthquakeDataDict =  json.load(inputfile)

# %% [raw]
# specificWeatherDataDict['2014-01']

# %% [raw]
# earthquakeDataDict['2014']['第005號']

# %% [markdown]
# # MAIN

# %% [markdown]
# specificWeatherDataDict[dateYM].keys()

# %%
def ListSum(inputList):
    sumInt = 0
    for temp in inputList:
        try:
            sumInt += float(temp)
        except:
            continue
    return sumInt

# %%
for year in sorted(earthquakeDataDict.keys()):
    print(year)
    deltaDict[year] = dict()
    for num in sorted(earthquakeDataDict[year].keys()):
        try: 
            deltaDict[year][num] = dict()
            print(num, end="->")
            dateYMD = "%s-%s"%(year, earthquakeDataDict[year][num]['date'])
            dateYM = dateYMD.rsplit("-",1)[0]
            loca = earthquakeDataDict[year][num]['location']
            #額外處理
            if "桃園" in loca:
                temp = loca.split("縣")
                loca = temp[0] + "市" 
            print(loca,dateYMD,">")
            #確認有，雖多仍做
            if loca in specificWeatherDataDict[dateYM].keys():
                #蒐集資料
                dataListDictTemp = dict()
                for dataType in needDataList[1:]:#["Precp", "RH", "StnPres", "Temperature"]:
                    dataListDictTemp[dataType+"List"] = list()
                # 讀取 取前三、後三，共六
                dateSeq = earthquakeDataDict[year][num]['dateSeq']
                #print(dateSeq)
                for dateLoop in dateSeq:
                    ym = dateLoop.rsplit('-',1)[0]
                    #d = "%0.2d"%(int(dateLoop.rsplit('-',1)[1]))
                    d = "%d"%(int(dateLoop.rsplit('-',1)[1]))
                    #print(ym, d)
                    for dataType in needDataList[1:]:#["Precp", "RH", "StnPres", "Temperature"]:
                        dataListDictTemp[dataType+"List"].append(specificWeatherDataDict[ym][loca][d][dataType])
                # 運算
                for dataType in needDataList[1:]:#["Precp", "RH", "StnPres", "Temperature"]:
                    before = ListSum(dataListDictTemp[dataType+"List"][0:dayInterval]) / dayInterval
                    after = ListSum(dataListDictTemp[dataType+"List"][-dayInterval:]) / dayInterval

                    deltaDict[year][num][dataType+"_delta"] = after - before
            else:
                print("not in")
        except KeyError as e:
            print("error", e, "[ym][loca][d][dataType]",ym,loca,d,dataType)
            continue
# Out:
# 2011
# 第001號->宜蘭縣 2011-01-02 >
# error '1' [ym][loca][d][dataType] 2011-01 宜蘭縣 1 Temperature
# 第002號->宜蘭縣 2011-01-10 >
# error '7' [ym][loca][d][dataType] 2011-01 宜蘭縣 7 Temperature
# 第003號->宜蘭縣 2011-01-11 >
# error '8' [ym][loca][d][dataType] 2011-01 宜蘭縣 8 Temperature
# 第004號->宜蘭縣 2011-01-15 >
# 第005號->臺中市 2011-01-25 >
# 第006號->嘉義縣 2011-01-25 >
# 第007號->高雄市 2011-01-28 >
# 第008號->花蓮縣 2011-02-01 >
# error '1' [ym][loca][d][dataType] 2011-02 花蓮縣 1 Temperature
# 第009號->花蓮縣 2011-02-01 >
# error '1' [ym][loca][d][dataType] 2011-02 花蓮縣 1 Temperature
# 第010號->花蓮縣 2011-02-03 >
# error '1' [ym][loca][d][dataType] 2011-02 花蓮縣 1 Temperature
# 第011號->宜蘭縣 2011-02-05 >
# 第012號->花蓮縣 2011-02-07 >
# error '4' [ym][loca][d][dataType] 2011-02 花蓮縣 4 Temperature
# 第013號->花蓮縣 2011-02-07 >
# error '4' [ym][loca][d][dataType] 2011-02 花蓮縣 4 Temperature
# 第014號->花蓮縣 2011-02-07 >
# error '4' [ym][loca][d][dataType] 2011-02 花蓮縣 4 Temperature
# 第015號->花蓮縣 2011-02-07 >
# error '4' [ym][loca][d][dataType] 2011-02 花蓮縣 4 Temperature
# 第016號->臺中市 2011-02-08 >
# 第017號->南投縣 2011-02-09 >
# 第018號->雲林縣 2011-02-26 >
# error '1' [ym][loca][d][dataType] 2011-03 雲林縣 1 Temperature
# 第019號->花蓮縣 2011-03-02 >
# error '1' [ym][loca][d][dataType] 2011-03 花蓮縣 1 Temperature
# 第020號->花蓮縣 2011-03-05 >
# error '2' [ym][loca][d][dataType] 2011-03 花蓮縣 2 Temperature
# 第021號->宜蘭縣 2011-03-05 >
# error '2' [ym][loca][d][dataType] 2011-03 宜蘭縣 2 Temperature
# 第022號->花蓮縣 2011-03-08 >
# error '5' [ym][loca][d][dataType] 2011-03 花蓮縣 5 Temperature
# 第023號->雲林縣 2011-03-12 >
# 第024號->雲林縣 2011-03-12 >
# 第025號->臺東縣 2011-03-15 >
# error '12' [ym][loca][d][dataType] 2011-03 臺東縣 12 Temperature
# 第026號->屏東縣 2011-03-16 >
# error '13' [ym][loca][d][dataType] 2011-03 屏東縣 13 Temperature
# 第027號->花蓮縣 2011-03-18 >
# error '15' [ym][loca][d][dataType] 2011-03 花蓮縣 15 Temperature
# 第028號->宜蘭縣 2011-03-19 >
# error '16' [ym][loca][d][dataType] 2011-03 宜蘭縣 16 Temperature
# 第029號->臺東縣 2011-03-20 >
# error '17' [ym][loca][d][dataType] 2011-03 臺東縣 17 Temperature
# 第030號->花蓮縣 2011-03-21 >
# error '18' [ym][loca][d][dataType] 2011-03 花蓮縣 18 Temperature
# 第031號->花蓮縣 2011-03-21 >
# error '18' [ym][loca][d][dataType] 2011-03 花蓮縣 18 Temperature
# 第032號->屏東縣 2011-03-24 >
# 第033號->臺東縣 2011-03-24 >
# error '21' [ym][loca][d][dataType] 2011-03 臺東縣 21 Temperature
# 第034號->宜蘭縣 2011-03-26 >
# 第035號->花蓮縣 2011-03-30 >
# error '27' [ym][loca][d][dataType] 2011-03 花蓮縣 27 Temperature
# 第036號->臺東縣 2011-03-31 >
# error '1' [ym][loca][d][dataType] 2011-04 臺東縣 1 Temperature
# 第037號->花蓮縣 2011-04-01 >
# error '1' [ym][loca][d][dataType] 2011-04 花蓮縣 1 Temperature
# 第038號->花蓮縣 2011-04-05 >
# error '2' [ym][loca][d][dataType] 2011-04 花蓮縣 2 Temperature
# 第039號->花蓮縣 2011-04-05 >
# error '2' [ym][loca][d][dataType] 2011-04 花蓮縣 2 Temperature
# 第040號->花蓮縣 2011-04-07 >
# error '4' [ym][loca][d][dataType] 2011-04 花蓮縣 4 Temperature
# 第041號->花蓮縣 2011-04-08 >
# error '5' [ym][loca][d][dataType] 2011-04 花蓮縣 5 Temperature
# 第042號->雲林縣 2011-04-11 >
# 第043號->新北市 2011-04-11 >
# 第044號->高雄市 2011-04-12 >
# error '9' [ym][loca][d][dataType] 2011-04 高雄市 9 Temperature
# 第045號->高雄市 2011-04-16 >
# error '13' [ym][loca][d][dataType] 2011-04 高雄市 13 Temperature
# 第046號->宜蘭縣 2011-04-16 >
# error '13' [ym][loca][d][dataType] 2011-04 宜蘭縣 13 Temperature
# 第047號->花蓮縣 2011-04-22 >
# error '19' [ym][loca][d][dataType] 2011-04 花蓮縣 19 Temperature
# 第048號->高雄市 2011-04-27 >
# 第049號->臺東縣 2011-04-29 >
# error '1' [ym][loca][d][dataType] 2011-05 臺東縣 1 Temperature
# 第050號->宜蘭縣 2011-04-30 >
# error '1' [ym][loca][d][dataType] 2011-05 宜蘭縣 1 Temperature
# 第051號->花蓮縣 2011-05-01 >
# error '1' [ym][loca][d][dataType] 2011-05 花蓮縣 1 Temperature
# 第052號->嘉義縣 2011-05-02 >
# 第053號->花蓮縣 2011-05-03 >
# error '1' [ym][loca][d][dataType] 2011-05 花蓮縣 1 Temperature
# 第054號->花蓮縣 2011-05-04 >
# error '1' [ym][loca][d][dataType] 2011-05 花蓮縣 1 Temperature
# 第055號->臺東縣 2011-05-07 >
# error '4' [ym][loca][d][dataType] 2011-05 臺東縣 4 Temperature
# 第056號->宜蘭縣 2011-05-07 >
# error '4' [ym][loca][d][dataType] 2011-05 宜蘭縣 4 Temperature
# 第057號->臺南市 2011-05-08 >
# 第058號->花蓮縣 2011-05-21 >
# error '18' [ym][loca][d][dataType] 2011-05 花蓮縣 18 Temperature
# 第059號->花蓮縣 2011-05-22 >
# error '19' [ym][loca][d][dataType] 2011-05 花蓮縣 19 Temperature
# 第060號->花蓮縣 2011-05-22 >
# error '19' [ym][loca][d][dataType] 2011-05 花蓮縣 19 Temperature
# 第061號->南投縣 2011-05-23 >
# 第062號->南投縣 2011-05-23 >
# 第063號->宜蘭縣 2011-05-24 >
# 第064號->花蓮縣 2011-05-25 >
# 第065號->臺東縣 2011-05-30 >
# error '27' [ym][loca][d][dataType] 2011-05 臺東縣 27 Temperature
# 第066號->臺東縣 2011-06-03 >
# error '1' [ym][loca][d][dataType] 2011-06 臺東縣 1 Temperature
# 第067號->雲林縣 2011-06-03 >
# 第068號->花蓮縣 2011-06-08 >
# error '5' [ym][loca][d][dataType] 2011-06 花蓮縣 5 Temperature
# 第069號->宜蘭縣 2011-06-09 >
# error '6' [ym][loca][d][dataType] 2011-06 宜蘭縣 6 Temperature
# 第070號->花蓮縣 2011-06-10 >
# error '7' [ym][loca][d][dataType] 2011-06 花蓮縣 7 Temperature
# 第071號->臺東縣 2011-06-10 >
# error '7' [ym][loca][d][dataType] 2011-06 臺東縣 7 Temperature
# 第072號->花蓮縣 2011-06-12 >
# error '9' [ym][loca][d][dataType] 2011-06 花蓮縣 9 Temperature
# 第073號->花蓮縣 2011-06-15 >
# error '12' [ym][loca][d][dataType] 2011-06 花蓮縣 12 Temperature
# 第074號->宜蘭縣 2011-06-16 >
# error '13' [ym][loca][d][dataType] 2011-06 宜蘭縣 13 Temperature
# 第075號->臺東縣 2011-06-19 >
# error '16' [ym][loca][d][dataType] 2011-06 臺東縣 16 Temperature
# 第076號->宜蘭縣 2011-06-19 >
# error '16' [ym][loca][d][dataType] 2011-06 宜蘭縣 16 Temperature
# 第077號->臺東縣 2011-06-24 >
# error '21' [ym][loca][d][dataType] 2011-06 臺東縣 21 Temperature
# 第078號->花蓮縣 2011-06-26 >
# error '23' [ym][loca][d][dataType] 2011-06 花蓮縣 23 Temperature
# 第079號->南投縣 2011-06-26 >
# 第080號->屏東縣 2011-06-30 >
# 第081號->花蓮縣 2011-07-01 >
# error '1' [ym][loca][d][dataType] 2011-07 花蓮縣 1 Temperature
# 第082號->花蓮縣 2011-07-02 >
# error '1' [ym][loca][d][dataType] 2011-07 花蓮縣 1 Temperature
# 第083號->花蓮縣 2011-07-02 >
# error '1' [ym][loca][d][dataType] 2011-07 花蓮縣 1 Temperature
# 第084號->臺東縣 2011-07-02 >
# error '1' [ym][loca][d][dataType] 2011-07 臺東縣 1 Temperature
# 第085號->宜蘭縣 2011-07-03 >
# error '1' [ym][loca][d][dataType] 2011-07 宜蘭縣 1 Temperature
# 第086號->宜蘭縣 2011-07-03 >
# error '1' [ym][loca][d][dataType] 2011-07 宜蘭縣 1 Temperature
# 第087號->花蓮縣 2011-07-05 >
# error '2' [ym][loca][d][dataType] 2011-07 花蓮縣 2 Temperature
# 第088號->花蓮縣 2011-07-06 >
# error '3' [ym][loca][d][dataType] 2011-07 花蓮縣 3 Temperature
# 第089號->花蓮縣 2011-07-06 >
# error '3' [ym][loca][d][dataType] 2011-07 花蓮縣 3 Temperature
# 第090號->花蓮縣 2011-07-07 >
# error '4' [ym][loca][d][dataType] 2011-07 花蓮縣 4 Temperature
# 第091號->花蓮縣 2011-07-07 >
# error '4' [ym][loca][d][dataType] 2011-07 花蓮縣 4 Temperature
# 第092號->花蓮縣 2011-07-07 >
# error '4' [ym][loca][d][dataType] 2011-07 花蓮縣 4 Temperature
# 第093號->花蓮縣 2011-07-07 >
# error '4' [ym][loca][d][dataType] 2011-07 花蓮縣 4 Temperature
# 第094號->花蓮縣 2011-07-07 >
# error '4' [ym][loca][d][dataType] 2011-07 花蓮縣 4 Temperature
# 第095號->花蓮縣 2011-07-07 >
# error '4' [ym][loca][d][dataType] 2011-07 花蓮縣 4 Temperature
# 第096號->花蓮縣 2011-07-08 >
# error '5' [ym][loca][d][dataType] 2011-07 花蓮縣 5 Temperature
# 第097號->花蓮縣 2011-07-08 >
# error '5' [ym][loca][d][dataType] 2011-07 花蓮縣 5 Temperature
# 第098號->花蓮縣 2011-07-08 >
# error '5' [ym][loca][d][dataType] 2011-07 花蓮縣 5 Temperature
# 第099號->花蓮縣 2011-07-09 >
# error '6' [ym][loca][d][dataType] 2011-07 花蓮縣 6 Temperature
# 第100號->花蓮縣 2011-07-12 >
# error '9' [ym][loca][d][dataType] 2011-07 花蓮縣 9 Temperature
# 第101號->花蓮縣 2011-07-15 >
# error '12' [ym][loca][d][dataType] 2011-07 花蓮縣 12 Temperature
# 第102號->花蓮縣 2011-07-15 >
# error '12' [ym][loca][d][dataType] 2011-07 花蓮縣 12 Temperature
# 第103號->花蓮縣 2011-07-15 >
# error '12' [ym][loca][d][dataType] 2011-07 花蓮縣 12 Temperature
# 第104號->新竹縣 2011-07-16 >
# 第105號->花蓮縣 2011-07-16 >
# error '13' [ym][loca][d][dataType] 2011-07 花蓮縣 13 Temperature
# 第106號->花蓮縣 2011-07-18 >
# error '15' [ym][loca][d][dataType] 2011-07 花蓮縣 15 Temperature
# 第107號->嘉義市 2011-07-18 >
# error '15' [ym][loca][d][dataType] 2011-07 嘉義市 15 Temperature
# 第108號->花蓮縣 2011-07-18 >
# error '15' [ym][loca][d][dataType] 2011-07 花蓮縣 15 Temperature
# 第109號->臺東縣 2011-07-19 >
# error '16' [ym][loca][d][dataType] 2011-07 臺東縣 16 Temperature
# 第110號->嘉義市 2011-07-19 >
# error '16' [ym][loca][d][dataType] 2011-07 嘉義市 16 Temperature
# 第111號->花蓮縣 2011-07-19 >
# error '16' [ym][loca][d][dataType] 2011-07 花蓮縣 16 Temperature
# 第112號->嘉義市 2011-07-19 >
# error '16' [ym][loca][d][dataType] 2011-07 嘉義市 16 Temperature
# 第113號->花蓮縣 2011-07-20 >
# error '17' [ym][loca][d][dataType] 2011-07 花蓮縣 17 Temperature
# 第114號->嘉義市 2011-07-20 >
# 第115號->臺東縣 2011-07-26 >
# 第116號->花蓮縣 2011-07-29 >
# error '1' [ym][loca][d][dataType] 2011-08 花蓮縣 1 Temperature
# 第117號->宜蘭縣 2011-07-29 >
# 第118號->彰化縣 2011-08-01 >
# 第119號->臺東縣 2011-08-04 >
# error '1' [ym][loca][d][dataType] 2011-08 臺東縣 1 Temperature
# 第120號->雲林縣 2011-08-07 >
# 第121號->南投縣 2011-08-07 >
# 第122號->花蓮縣 2011-08-11 >
# error '8' [ym][loca][d][dataType] 2011-08 花蓮縣 8 Temperature
# 第123號->花蓮縣 2011-08-12 >
# error '9' [ym][loca][d][dataType] 2011-08 花蓮縣 9 Temperature
# 第124號->花蓮縣 2011-08-24 >
# error '21' [ym][loca][d][dataType] 2011-08 花蓮縣 21 Temperature
# 第125號->臺東縣 2011-08-25 >
# error '22' [ym][loca][d][dataType] 2011-08 臺東縣 22 Temperature
# 第126號->花蓮縣 2011-08-28 >
# 第127號->臺東縣 2011-08-31 >
# error '1' [ym][loca][d][dataType] 2011-09 臺東縣 1 Temperature
# 第128號->宜蘭縣 2011-09-07 >
# error '4' [ym][loca][d][dataType] 2011-09 宜蘭縣 4 Temperature
# 第129號->臺東縣 2011-09-09 >
# 第130號->臺東縣 2011-09-09 >
# 第131號->臺東縣 2011-09-09 >
# 第132號->嘉義市 2011-09-13 >
# error '10' [ym][loca][d][dataType] 2011-09 嘉義市 10 Temperature
# 第133號->嘉義市 2011-09-16 >
# 第134號->花蓮縣 2011-09-22 >
# 第135號->花蓮縣 2011-09-22 >
# 第136號->花蓮縣 2011-09-22 >
# 第137號->花蓮縣 2011-09-22 >
# 第138號->宜蘭縣 2011-10-01 >
# error '1' [ym][loca][d][dataType] 2011-10 宜蘭縣 1 Temperature
# 第139號->新竹縣 2011-10-05 >
# 第140號->臺東縣 2011-10-09 >
# error '6' [ym][loca][d][dataType] 2011-10 臺東縣 6 Temperature
# 第141號->花蓮縣 2011-10-11 >
# error '8' [ym][loca][d][dataType] 2011-10 花蓮縣 8 Temperature
# 第142號->桃園市 2011-10-12 >
# 第143號->花蓮縣 2011-10-19 >
# error '16' [ym][loca][d][dataType] 2011-10 花蓮縣 16 Temperature
# 第144號->宜蘭縣 2011-10-24 >
# error '21' [ym][loca][d][dataType] 2011-10 宜蘭縣 21 Temperature
# 第145號->臺東縣 2011-10-24 >
# 第146號->花蓮縣 2011-10-28 >
# 第147號->基隆市 2011-10-30 >
# 第148號->宜蘭縣 2011-10-31 >
# error '1' [ym][loca][d][dataType] 2011-11 宜蘭縣 1 Temperature
# 第149號->花蓮縣 2011-11-04 >
# error '1' [ym][loca][d][dataType] 2011-11 花蓮縣 1 Temperature
# 第150號->花蓮縣 2011-11-05 >
# error '2' [ym][loca][d][dataType] 2011-11 花蓮縣 2 Temperature
# 第151號->嘉義縣 2011-11-06 >
# 第152號->宜蘭縣 2011-11-09 >
# error '6' [ym][loca][d][dataType] 2011-11 宜蘭縣 6 Temperature
# 第153號->花蓮縣 2011-11-16 >
# error '13' [ym][loca][d][dataType] 2011-11 花蓮縣 13 Temperature
# 第154號->花蓮縣 2011-11-16 >
# error '13' [ym][loca][d][dataType] 2011-11 花蓮縣 13 Temperature
# 第155號->宜蘭縣 2011-11-17 >
# error '14' [ym][loca][d][dataType] 2011-11 宜蘭縣 14 Temperature
# 第156號->花蓮縣 2011-11-19 >
# error '16' [ym][loca][d][dataType] 2011-11 花蓮縣 16 Temperature
# 第157號->嘉義市 2011-11-19 >
# 第158號->臺東縣 2011-11-19 >
# error '16' [ym][loca][d][dataType] 2011-11 臺東縣 16 Temperature
# 第159號->花蓮縣 2011-11-21 >
# error '18' [ym][loca][d][dataType] 2011-11 花蓮縣 18 Temperature
# 第160號->臺南市 2011-11-22 >
# 第161號->臺東縣 2011-12-02 >
# error '1' [ym][loca][d][dataType] 2011-12 臺東縣 1 Temperature
# 第162號->宜蘭縣 2011-12-02 >
# error '1' [ym][loca][d][dataType] 2011-12 宜蘭縣 1 Temperature
# 第163號->花蓮縣 2011-12-03 >
# error '1' [ym][loca][d][dataType] 2011-12 花蓮縣 1 Temperature
# 第164號->宜蘭縣 2011-12-04 >
# error '1' [ym][loca][d][dataType] 2011-12 宜蘭縣 1 Temperature
# 第165號->臺東縣 2011-12-05 >
# 第166號->宜蘭縣 2011-12-08 >
# 第167號->花蓮縣 2011-12-11 >
# error '8' [ym][loca][d][dataType] 2011-12 花蓮縣 8 Temperature
# 第168號->花蓮縣 2011-12-12 >
# error '9' [ym][loca][d][dataType] 2011-12 花蓮縣 9 Temperature
# 第169號->花蓮縣 2011-12-14 >
# error '11' [ym][loca][d][dataType] 2011-12 花蓮縣 11 Temperature
# 第170號->花蓮縣 2011-12-15 >
# error '12' [ym][loca][d][dataType] 2011-12 花蓮縣 12 Temperature
# 第171號->花蓮縣 2011-12-17 >
# error '14' [ym][loca][d][dataType] 2011-12 花蓮縣 14 Temperature
# 第172號->花蓮縣 2011-12-19 >
# 2012
# 第001號->花蓮縣 2012-01-04 >
# error '1' [ym][loca][d][dataType] 2012-01 花蓮縣 1 Temperature
# 第002號->花蓮縣 2012-01-04 >
# error '1' [ym][loca][d][dataType] 2012-01 花蓮縣 1 Temperature
# 第003號->花蓮縣 2012-01-04 >
# error '1' [ym][loca][d][dataType] 2012-01 花蓮縣 1 Temperature
# 第004號->嘉義市 2012-01-05 >
# error '2' [ym][loca][d][dataType] 2012-01 嘉義市 2 Temperature
# 第005號->臺南市 2012-01-07 >
# 第006號->花蓮縣 2012-01-09 >
# error '6' [ym][loca][d][dataType] 2012-01 花蓮縣 6 Temperature
# 第007號->花蓮縣 2012-01-09 >
# error '6' [ym][loca][d][dataType] 2012-01 花蓮縣 6 Temperature
# 第008號->花蓮縣 2012-01-09 >
# error '6' [ym][loca][d][dataType] 2012-01 花蓮縣 6 Temperature
# 第009號->花蓮縣 2012-01-10 >
# error '7' [ym][loca][d][dataType] 2012-01 花蓮縣 7 Temperature
# 第010號->花蓮縣 2012-01-10 >
# error '7' [ym][loca][d][dataType] 2012-01 花蓮縣 7 Temperature
# 第011號->花蓮縣 2012-01-10 >
# error '7' [ym][loca][d][dataType] 2012-01 花蓮縣 7 Temperature
# 第012號->花蓮縣 2012-01-16 >
# error '13' [ym][loca][d][dataType] 2012-01 花蓮縣 13 Temperature
# 第013號->宜蘭縣 2012-01-16 >
# error '13' [ym][loca][d][dataType] 2012-01 宜蘭縣 13 Temperature
# 第014號->宜蘭縣 2012-01-16 >
# error '13' [ym][loca][d][dataType] 2012-01 宜蘭縣 13 Temperature
# 第015號->花蓮縣 2012-01-17 >
# error '14' [ym][loca][d][dataType] 2012-01 花蓮縣 14 Temperature
# 第016號->宜蘭縣 2012-01-18 >
# error '15' [ym][loca][d][dataType] 2012-01 宜蘭縣 15 Temperature
# 第017號->嘉義市 2012-01-18 >
# 第018號->宜蘭縣 2012-01-20 >
# error '17' [ym][loca][d][dataType] 2012-01 宜蘭縣 17 Temperature
# 第019號->高雄市 2012-01-21 >
# 第020號->宜蘭縣 2012-01-25 >
# 第021號->花蓮縣 2012-01-26 >
# error '23' [ym][loca][d][dataType] 2012-01 花蓮縣 23 Temperature
# 第022號->花蓮縣 2012-01-30 >
# error '1' [ym][loca][d][dataType] 2012-02 花蓮縣 1 Temperature
# 第023號->屏東縣 2012-02-03 >
# error '1' [ym][loca][d][dataType] 2012-02 屏東縣 1 Temperature
# 第024號->宜蘭縣 2012-02-04 >
# 第025號->臺東縣 2012-02-06 >
# error '3' [ym][loca][d][dataType] 2012-02 臺東縣 3 Temperature
# 第026號->臺東縣 2012-02-06 >
# error '3' [ym][loca][d][dataType] 2012-02 臺東縣 3 Temperature
# 第027號->臺東縣 2012-02-06 >
# error '3' [ym][loca][d][dataType] 2012-02 臺東縣 3 Temperature
# 第028號->花蓮縣 2012-02-09 >
# error '6' [ym][loca][d][dataType] 2012-02 花蓮縣 6 Temperature
# 第029號->花蓮縣 2012-02-13 >
# error '10' [ym][loca][d][dataType] 2012-02 花蓮縣 10 Temperature
# 第030號->臺南市 2012-02-14 >
# 第031號->花蓮縣 2012-02-18 >
# error '15' [ym][loca][d][dataType] 2012-02 花蓮縣 15 Temperature
# 第032號->花蓮縣 2012-02-23 >
# error '20' [ym][loca][d][dataType] 2012-02 花蓮縣 20 Temperature
# 第033號->花蓮縣 2012-02-23 >
# error '20' [ym][loca][d][dataType] 2012-02 花蓮縣 20 Temperature
# 第034號->花蓮縣 2012-02-23 >
# error '20' [ym][loca][d][dataType] 2012-02 花蓮縣 20 Temperature
# 第035號->花蓮縣 2012-02-24 >
# error '21' [ym][loca][d][dataType] 2012-02 花蓮縣 21 Temperature
# 第036號->花蓮縣 2012-02-24 >
# error '21' [ym][loca][d][dataType] 2012-02 花蓮縣 21 Temperature
# 第037號->屏東縣 2012-02-26 >
# 第038號->屏東縣 2012-02-26 >
# 第039號->屏東縣 2012-02-26 >
# 第040號->花蓮縣 2012-03-01 >
# error '1' [ym][loca][d][dataType] 2012-03 花蓮縣 1 Temperature
# 第041號->臺東縣 2012-03-01 >
# error '1' [ym][loca][d][dataType] 2012-03 臺東縣 1 Temperature
# 第042號->花蓮縣 2012-03-01 >
# error '1' [ym][loca][d][dataType] 2012-03 花蓮縣 1 Temperature
# 第043號->花蓮縣 2012-03-04 >
# error '1' [ym][loca][d][dataType] 2012-03 花蓮縣 1 Temperature
# 第044號->屏東縣 2012-03-07 >
# error '4' [ym][loca][d][dataType] 2012-03 屏東縣 4 Temperature
# 第045號->屏東縣 2012-03-09 >
# 第046號->宜蘭縣 2012-03-11 >
# error '8' [ym][loca][d][dataType] 2012-03 宜蘭縣 8 Temperature
# 第047號->花蓮縣 2012-03-11 >
# error '8' [ym][loca][d][dataType] 2012-03 花蓮縣 8 Temperature
# 第048號->宜蘭縣 2012-03-18 >
# 第049號->臺東縣 2012-03-22 >
# 第050號->嘉義市 2012-03-24 >
# 第051號->花蓮縣 2012-03-24 >
# error '21' [ym][loca][d][dataType] 2012-03 花蓮縣 21 Temperature
# 第052號->花蓮縣 2012-03-25 >
# error '22' [ym][loca][d][dataType] 2012-03 花蓮縣 22 Temperature
# 第053號->花蓮縣 2012-04-03 >
# error '1' [ym][loca][d][dataType] 2012-04 花蓮縣 1 Temperature
# 第054號->花蓮縣 2012-04-06 >
# error '3' [ym][loca][d][dataType] 2012-04 花蓮縣 3 Temperature
# 第055號->花蓮縣 2012-04-07 >
# error '4' [ym][loca][d][dataType] 2012-04 花蓮縣 4 Temperature
# 第056號->花蓮縣 2012-04-08 >
# error '5' [ym][loca][d][dataType] 2012-04 花蓮縣 5 Temperature
# 第057號->花蓮縣 2012-04-08 >
# error '5' [ym][loca][d][dataType] 2012-04 花蓮縣 5 Temperature
# 第058號->花蓮縣 2012-04-09 >
# error '6' [ym][loca][d][dataType] 2012-04 花蓮縣 6 Temperature
# 第059號->臺東縣 2012-04-11 >
# 第060號->嘉義市 2012-04-12 >
# 第061號->花蓮縣 2012-04-16 >
# error '13' [ym][loca][d][dataType] 2012-04 花蓮縣 13 Temperature
# 第062號->花蓮縣 2012-04-16 >
# error '13' [ym][loca][d][dataType] 2012-04 花蓮縣 13 Temperature
# 第063號->花蓮縣 2012-04-18 >
# error '15' [ym][loca][d][dataType] 2012-04 花蓮縣 15 Temperature
# 第064號->花蓮縣 2012-04-19 >
# error '16' [ym][loca][d][dataType] 2012-04 花蓮縣 16 Temperature
# 第065號->花蓮縣 2012-04-27 >
# error '24' [ym][loca][d][dataType] 2012-04 花蓮縣 24 Temperature
# 第066號->屏東縣 2012-04-28 >
# 第067號->花蓮縣 2012-05-01 >
# error '1' [ym][loca][d][dataType] 2012-05 花蓮縣 1 Temperature
# 第068號->臺南市 2012-05-09 >
# 第069號->宜蘭縣 2012-05-16 >
# error '13' [ym][loca][d][dataType] 2012-05 宜蘭縣 13 Temperature
# 第070號->花蓮縣 2012-05-21 >
# error '18' [ym][loca][d][dataType] 2012-05 花蓮縣 18 Temperature
# 第071號->宜蘭縣 2012-05-21 >
# 第072號->宜蘭縣 2012-05-21 >
# 第073號->臺東縣 2012-05-22 >
# error '19' [ym][loca][d][dataType] 2012-05 臺東縣 19 Temperature
# 第074號->臺東縣 2012-05-22 >
# error '19' [ym][loca][d][dataType] 2012-05 臺東縣 19 Temperature
# 第075號->花蓮縣 2012-05-23 >
# error '20' [ym][loca][d][dataType] 2012-05 花蓮縣 20 Temperature
# 第076號->花蓮縣 2012-05-24 >
# error '21' [ym][loca][d][dataType] 2012-05 花蓮縣 21 Temperature
# 第077號->臺東縣 2012-05-28 >
# error '25' [ym][loca][d][dataType] 2012-05 臺東縣 25 Temperature
# 第078號->臺東縣 2012-05-30 >
# error '27' [ym][loca][d][dataType] 2012-05 臺東縣 27 Temperature
# 第079號->臺東縣 2012-05-30 >
# error '27' [ym][loca][d][dataType] 2012-05 臺東縣 27 Temperature
# 第080號->花蓮縣 2012-05-31 >
# error '1' [ym][loca][d][dataType] 2012-06 花蓮縣 1 Temperature
# 第081號->嘉義市 2012-06-02 >
# error '1' [ym][loca][d][dataType] 2012-06 嘉義市 1 Temperature
# 第082號->臺東縣 2012-06-03 >
# error '1' [ym][loca][d][dataType] 2012-06 臺東縣 1 Temperature
# 第083號->臺東縣 2012-06-06 >
# 第084號->屏東縣 2012-06-08 >
# error '5' [ym][loca][d][dataType] 2012-06 屏東縣 5 Temperature
# 第085號->嘉義市 2012-06-08 >
# 第086號->屏東縣 2012-06-09 >
# error '6' [ym][loca][d][dataType] 2012-06 屏東縣 6 Temperature
# 第087號->宜蘭縣 2012-06-10 >
# error '7' [ym][loca][d][dataType] 2012-06 宜蘭縣 7 Temperature
# 第088號->宜蘭縣 2012-06-10 >
# error '7' [ym][loca][d][dataType] 2012-06 宜蘭縣 7 Temperature
# 第089號->花蓮縣 2012-06-10 >
# error '7' [ym][loca][d][dataType] 2012-06 花蓮縣 7 Temperature
# 第090號->桃園市 2012-06-13 >
# 第091號->桃園市 2012-06-13 >
# 第092號->花蓮縣 2012-06-14 >
# error '11' [ym][loca][d][dataType] 2012-06 花蓮縣 11 Temperature
# 第093號->花蓮縣 2012-06-14 >
# error '11' [ym][loca][d][dataType] 2012-06 花蓮縣 11 Temperature
# 第094號->花蓮縣 2012-06-14 >
# error '11' [ym][loca][d][dataType] 2012-06 花蓮縣 11 Temperature
# 第095號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第096號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第097號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第098號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第099號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第100號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第101號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第102號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第103號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第104號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第105號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第106號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第107號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第108號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第109號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第110號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第111號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第112號->宜蘭縣 2012-06-15 >
# 第113號->花蓮縣 2012-06-15 >
# error '12' [ym][loca][d][dataType] 2012-06 花蓮縣 12 Temperature
# 第114號->花蓮縣 2012-06-16 >
# error '13' [ym][loca][d][dataType] 2012-06 花蓮縣 13 Temperature
# 第115號->花蓮縣 2012-06-16 >
# error '13' [ym][loca][d][dataType] 2012-06 花蓮縣 13 Temperature
# 第116號->花蓮縣 2012-06-17 >
# error '14' [ym][loca][d][dataType] 2012-06 花蓮縣 14 Temperature
# 第117號->花蓮縣 2012-06-17 >
# error '14' [ym][loca][d][dataType] 2012-06 花蓮縣 14 Temperature
# 第118號->花蓮縣 2012-06-17 >
# error '14' [ym][loca][d][dataType] 2012-06 花蓮縣 14 Temperature
# 第119號->花蓮縣 2012-06-17 >
# error '14' [ym][loca][d][dataType] 2012-06 花蓮縣 14 Temperature
# 第120號->花蓮縣 2012-06-17 >
# error '14' [ym][loca][d][dataType] 2012-06 花蓮縣 14 Temperature
# 第121號->花蓮縣 2012-06-17 >
# error '14' [ym][loca][d][dataType] 2012-06 花蓮縣 14 Temperature
# 第122號->花蓮縣 2012-06-17 >
# error '14' [ym][loca][d][dataType] 2012-06 花蓮縣 14 Temperature
# 第123號->花蓮縣 2012-06-17 >
# error '14' [ym][loca][d][dataType] 2012-06 花蓮縣 14 Temperature
# 第124號->花蓮縣 2012-06-17 >
# error '14' [ym][loca][d][dataType] 2012-06 花蓮縣 14 Temperature
# 第125號->花蓮縣 2012-06-18 >
# error '15' [ym][loca][d][dataType] 2012-06 花蓮縣 15 Temperature
# 第126號->花蓮縣 2012-06-18 >
# error '15' [ym][loca][d][dataType] 2012-06 花蓮縣 15 Temperature
# 第127號->花蓮縣 2012-06-18 >
# error '15' [ym][loca][d][dataType] 2012-06 花蓮縣 15 Temperature
# 第128號->花蓮縣 2012-06-18 >
# error '15' [ym][loca][d][dataType] 2012-06 花蓮縣 15 Temperature
# 第129號->花蓮縣 2012-06-18 >
# error '15' [ym][loca][d][dataType] 2012-06 花蓮縣 15 Temperature
# 第130號->花蓮縣 2012-06-18 >
# error '15' [ym][loca][d][dataType] 2012-06 花蓮縣 15 Temperature
# 第131號->花蓮縣 2012-06-19 >
# error '16' [ym][loca][d][dataType] 2012-06 花蓮縣 16 Temperature
# 第132號->花蓮縣 2012-06-19 >
# error '16' [ym][loca][d][dataType] 2012-06 花蓮縣 16 Temperature
# 第133號->花蓮縣 2012-06-19 >
# error '16' [ym][loca][d][dataType] 2012-06 花蓮縣 16 Temperature
# 第134號->花蓮縣 2012-06-19 >
# error '16' [ym][loca][d][dataType] 2012-06 花蓮縣 16 Temperature
# 第135號->屏東縣 2012-06-19 >
# 第136號->花蓮縣 2012-06-20 >
# error '17' [ym][loca][d][dataType] 2012-06 花蓮縣 17 Temperature
# 第137號->花蓮縣 2012-06-20 >
# error '17' [ym][loca][d][dataType] 2012-06 花蓮縣 17 Temperature
# 第138號->花蓮縣 2012-06-20 >
# error '17' [ym][loca][d][dataType] 2012-06 花蓮縣 17 Temperature
# 第139號->花蓮縣 2012-06-22 >
# error '19' [ym][loca][d][dataType] 2012-06 花蓮縣 19 Temperature
# 第140號->花蓮縣 2012-06-22 >
# error '19' [ym][loca][d][dataType] 2012-06 花蓮縣 19 Temperature
# 第141號->花蓮縣 2012-06-22 >
# error '19' [ym][loca][d][dataType] 2012-06 花蓮縣 19 Temperature
# 第142號->花蓮縣 2012-06-22 >
# error '19' [ym][loca][d][dataType] 2012-06 花蓮縣 19 Temperature
# 第143號->花蓮縣 2012-06-27 >
# 第144號->臺東縣 2012-07-07 >
# error '4' [ym][loca][d][dataType] 2012-07 臺東縣 4 Temperature
# 第145號->臺東縣 2012-07-07 >
# error '4' [ym][loca][d][dataType] 2012-07 臺東縣 4 Temperature
# 第146號->宜蘭縣 2012-07-10 >
# error '7' [ym][loca][d][dataType] 2012-07 宜蘭縣 7 Temperature
# 第147號->花蓮縣 2012-07-17 >
# error '14' [ym][loca][d][dataType] 2012-07 花蓮縣 14 Temperature
# 第148號->花蓮縣 2012-07-18 >
# error '15' [ym][loca][d][dataType] 2012-07 花蓮縣 15 Temperature
# 第149號->新北市 2012-07-20 >
# 第150號->花蓮縣 2012-07-21 >
# 第151號->宜蘭縣 2012-07-23 >
# 第152號->臺東縣 2012-07-29 >
# error '1' [ym][loca][d][dataType] 2012-08 臺東縣 1 Temperature
# 第153號->桃園市 2012-07-31 >
# 第154號->屏東縣 2012-08-04 >
# 第155號->花蓮縣 2012-08-14 >
# error '11' [ym][loca][d][dataType] 2012-08 花蓮縣 11 Temperature
# 第156號->花蓮縣 2012-08-15 >
# error '12' [ym][loca][d][dataType] 2012-08 花蓮縣 12 Temperature
# 第157號->臺東縣 2012-08-15 >
# error '12' [ym][loca][d][dataType] 2012-08 臺東縣 12 Temperature
# 第158號->花蓮縣 2012-08-15 >
# error '12' [ym][loca][d][dataType] 2012-08 花蓮縣 12 Temperature
# 第159號->花蓮縣 2012-08-16 >
# error '13' [ym][loca][d][dataType] 2012-08 花蓮縣 13 Temperature
# 第160號->花蓮縣 2012-08-17 >
# error '14' [ym][loca][d][dataType] 2012-08 花蓮縣 14 Temperature
# 第161號->花蓮縣 2012-08-17 >
# error '14' [ym][loca][d][dataType] 2012-08 花蓮縣 14 Temperature
# 第162號->花蓮縣 2012-08-18 >
# error '15' [ym][loca][d][dataType] 2012-08 花蓮縣 15 Temperature
# 第163號->花蓮縣 2012-08-20 >
# error '17' [ym][loca][d][dataType] 2012-08 花蓮縣 17 Temperature
# 第164號->花蓮縣 2012-08-20 >
# error '17' [ym][loca][d][dataType] 2012-08 花蓮縣 17 Temperature
# 第165號->花蓮縣 2012-08-20 >
# error '17' [ym][loca][d][dataType] 2012-08 花蓮縣 17 Temperature
# 第166號->臺東縣 2012-08-22 >
# error '19' [ym][loca][d][dataType] 2012-08 臺東縣 19 Temperature
# 第167號->花蓮縣 2012-08-23 >
# 第168號->臺東縣 2012-08-29 >
# error '1' [ym][loca][d][dataType] 2012-09 臺東縣 1 Temperature
# 第169號->新竹市 2012-08-31 >
# error '28' [ym][loca][d][dataType] 2012-08 新竹市 28 Temperature
# 第170號->新竹市 2012-08-31 >
# error '28' [ym][loca][d][dataType] 2012-08 新竹市 28 Temperature
# 第171號->臺南市 2012-09-01 >
# 第172號->新竹市 2012-09-03 >
# error '1' [ym][loca][d][dataType] 2012-09 新竹市 1 Temperature
# 第173號->臺東縣 2012-09-05 >
# error '2' [ym][loca][d][dataType] 2012-09 臺東縣 2 Temperature
# 第174號->臺東縣 2012-09-05 >
# error '2' [ym][loca][d][dataType] 2012-09 臺東縣 2 Temperature
# 第175號->新竹市 2012-09-19 >
# 第176號->臺東縣 2012-09-25 >
# error '22' [ym][loca][d][dataType] 2012-09 臺東縣 22 Temperature
# 第177號->嘉義市 2012-09-25 >
# 第178號->臺東縣 2012-09-26 >
# 第179號->宜蘭縣 2012-09-26 >
# 第180號->臺北市 2012-10-13 >
# 第181號->南投縣 2012-10-13 >
# 第182號->花蓮縣 2012-10-13 >
# 第183號->宜蘭縣 2012-10-14 >
# error '11' [ym][loca][d][dataType] 2012-10 宜蘭縣 11 Temperature
# 第184號->臺中市 2012-10-18 >
# 第185號->宜蘭縣 2012-10-20 >
# 第186號->嘉義市 2012-10-24 >
# 第187號->高雄市 2012-10-25 >
# error '22' [ym][loca][d][dataType] 2012-10 高雄市 22 Temperature
# 第188號->高雄市 2012-10-25 >
# error '22' [ym][loca][d][dataType] 2012-10 高雄市 22 Temperature
# 第189號->高雄市 2012-11-03 >
# 第190號->花蓮縣 2012-11-05 >
# error '2' [ym][loca][d][dataType] 2012-11 花蓮縣 2 Temperature
# 第191號->花蓮縣 2012-11-06 >
# error '3' [ym][loca][d][dataType] 2012-11 花蓮縣 3 Temperature
# 第192號->臺東縣 2012-11-07 >
# error '4' [ym][loca][d][dataType] 2012-11 臺東縣 4 Temperature
# 第193號->臺東縣 2012-11-10 >
# error '7' [ym][loca][d][dataType] 2012-11 臺東縣 7 Temperature
# 第194號->花蓮縣 2012-11-10 >
# error '7' [ym][loca][d][dataType] 2012-11 花蓮縣 7 Temperature
# 第195號->臺東縣 2012-11-11 >
# error '8' [ym][loca][d][dataType] 2012-11 臺東縣 8 Temperature
# 第196號->花蓮縣 2012-11-13 >
# error '10' [ym][loca][d][dataType] 2012-11 花蓮縣 10 Temperature
# 第197號->臺東縣 2012-11-21 >
# error '18' [ym][loca][d][dataType] 2012-11 臺東縣 18 Temperature
# 第198號->嘉義市 2012-11-29 >
# error '1' [ym][loca][d][dataType] 2012-12 嘉義市 1 Temperature
# 第199號->臺東縣 2012-11-29 >
# error '26' [ym][loca][d][dataType] 2012-11 臺東縣 26 Temperature
# 第200號->臺東縣 2012-11-30 >
# error '1' [ym][loca][d][dataType] 2012-12 臺東縣 1 Temperature
# 第201號->花蓮縣 2012-12-03 >
# error '1' [ym][loca][d][dataType] 2012-12 花蓮縣 1 Temperature
# 第202號->花蓮縣 2012-12-03 >
# error '1' [ym][loca][d][dataType] 2012-12 花蓮縣 1 Temperature
# 第203號->花蓮縣 2012-12-05 >
# error '2' [ym][loca][d][dataType] 2012-12 花蓮縣 2 Temperature
# 第204號->臺東縣 2012-12-11 >
# error '8' [ym][loca][d][dataType] 2012-12 臺東縣 8 Temperature
# 第205號->花蓮縣 2012-12-11 >
# error '8' [ym][loca][d][dataType] 2012-12 花蓮縣 8 Temperature
# 第206號->花蓮縣 2012-12-11 >
# error '8' [ym][loca][d][dataType] 2012-12 花蓮縣 8 Temperature
# 第207號->花蓮縣 2012-12-16 >
# error '13' [ym][loca][d][dataType] 2012-12 花蓮縣 13 Temperature
# 第208號->宜蘭縣 2012-12-17 >
# 第209號->花蓮縣 2012-12-22 >
# error '19' [ym][loca][d][dataType] 2012-12 花蓮縣 19 Temperature
# 第210號->臺東縣 2012-12-22 >
# error '19' [ym][loca][d][dataType] 2012-12 臺東縣 19 Temperature
# 第211號->臺東縣 2012-12-22 >
# error '19' [ym][loca][d][dataType] 2012-12 臺東縣 19 Temperature
# 第212號->花蓮縣 2012-12-23 >
# error '20' [ym][loca][d][dataType] 2012-12 花蓮縣 20 Temperature
# 第213號->臺東縣 2012-12-24 >
# 第214號->嘉義市 2012-12-31 >
# 2013
# 第001號->花蓮縣 2013-01-02 >
# error '1' [ym][loca][d][dataType] 2013-01 花蓮縣 1 Temperature
# 第002號->花蓮縣 2013-01-03 >
# error '1' [ym][loca][d][dataType] 2013-01 花蓮縣 1 Temperature
# 第003號->花蓮縣 2013-01-03 >
# error '1' [ym][loca][d][dataType] 2013-01 花蓮縣 1 Temperature
# 第004號->花蓮縣 2013-01-04 >
# error '1' [ym][loca][d][dataType] 2013-01 花蓮縣 1 Temperature
# 第005號->花蓮縣 2013-01-04 >
# error '1' [ym][loca][d][dataType] 2013-01 花蓮縣 1 Temperature
# 第006號->宜蘭縣 2013-01-05 >
# error '2' [ym][loca][d][dataType] 2013-01 宜蘭縣 2 Temperature
# 第007號->宜蘭縣 2013-01-07 >
# error '4' [ym][loca][d][dataType] 2013-01 宜蘭縣 4 Temperature
# 第008號->高雄市 2013-01-13 >
# 第009號->臺東縣 2013-01-14 >
# 第010號->宜蘭縣 2013-01-17 >
# error '14' [ym][loca][d][dataType] 2013-01 宜蘭縣 14 Temperature
# 第011號->宜蘭縣 2013-01-21 >
# 第012號->花蓮縣 2013-01-28 >
# error '25' [ym][loca][d][dataType] 2013-01 花蓮縣 25 Temperature
# 第013號->花蓮縣 2013-01-29 >
# error '26' [ym][loca][d][dataType] 2013-01 花蓮縣 26 Temperature
# 第014號->花蓮縣 2013-02-02 >
# error '1' [ym][loca][d][dataType] 2013-02 花蓮縣 1 Temperature
# 第015號->花蓮縣 2013-02-04 >
# error '1' [ym][loca][d][dataType] 2013-02 花蓮縣 1 Temperature
# 第016號->宜蘭縣 2013-02-06 >
# 第017號->花蓮縣 2013-02-06 >
# error '3' [ym][loca][d][dataType] 2013-02 花蓮縣 3 Temperature
# 第018號->花蓮縣 2013-02-17 >
# error '14' [ym][loca][d][dataType] 2013-02 花蓮縣 14 Temperature
# 第019號->花蓮縣 2013-02-17 >
# error '14' [ym][loca][d][dataType] 2013-02 花蓮縣 14 Temperature
# 第020號->高雄市 2013-02-19 >
# 第021號->嘉義市 2013-02-19 >
# 第022號->屏東縣 2013-02-19 >
# 第023號->臺東縣 2013-02-20 >
# 第024號->花蓮縣 2013-02-22 >
# 第025號->花蓮縣 2013-02-22 >
# 第026號->臺東縣 2013-03-04 >
# error '1' [ym][loca][d][dataType] 2013-03 臺東縣 1 Temperature
# 第027號->宜蘭縣 2013-03-06 >
# error '3' [ym][loca][d][dataType] 2013-03 宜蘭縣 3 Temperature
# 第028號->宜蘭縣 2013-03-07 >
# error '4' [ym][loca][d][dataType] 2013-03 宜蘭縣 4 Temperature
# 第029號->花蓮縣 2013-03-07 >
# error '4' [ym][loca][d][dataType] 2013-03 花蓮縣 4 Temperature
# 第030號->花蓮縣 2013-03-07 >
# error '4' [ym][loca][d][dataType] 2013-03 花蓮縣 4 Temperature
# 第031號->花蓮縣 2013-03-07 >
# error '4' [ym][loca][d][dataType] 2013-03 花蓮縣 4 Temperature
# 第032號->花蓮縣 2013-03-07 >
# error '4' [ym][loca][d][dataType] 2013-03 花蓮縣 4 Temperature
# 第033號->花蓮縣 2013-03-09 >
# error '6' [ym][loca][d][dataType] 2013-03 花蓮縣 6 Temperature
# 第034號->花蓮縣 2013-03-10 >
# error '7' [ym][loca][d][dataType] 2013-03 花蓮縣 7 Temperature
# 第035號->宜蘭縣 2013-03-12 >
# error '9' [ym][loca][d][dataType] 2013-03 宜蘭縣 9 Temperature
# 第036號->花蓮縣 2013-03-13 >
# error '10' [ym][loca][d][dataType] 2013-03 花蓮縣 10 Temperature
# 第037號->南投縣 2013-03-17 >
# error '14' [ym][loca][d][dataType] 2013-03 南投縣 14 Temperature
# 第038號->花蓮縣 2013-03-19 >
# 第039號->臺東縣 2013-03-20 >
# 第040號->宜蘭縣 2013-03-20 >
# 第041號->南投縣 2013-03-27 >
# error '24' [ym][loca][d][dataType] 2013-03 南投縣 24 Temperature
# 第042號->南投縣 2013-03-27 >
# error '24' [ym][loca][d][dataType] 2013-03 南投縣 24 Temperature
# 第043號->南投縣 2013-03-28 >
# error '25' [ym][loca][d][dataType] 2013-03 南投縣 25 Temperature
# 第044號->南投縣 2013-04-01 >
# 第045號->嘉義市 2013-04-02 >
# error '1' [ym][loca][d][dataType] 2013-04 嘉義市 1 Temperature
# 第046號->嘉義市 2013-04-06 >
# 第047號->花蓮縣 2013-04-08 >
# error '5' [ym][loca][d][dataType] 2013-04 花蓮縣 5 Temperature
# 第048號->花蓮縣 2013-04-08 >
# error '5' [ym][loca][d][dataType] 2013-04 花蓮縣 5 Temperature
# 第049號->宜蘭縣 2013-04-09 >
# error '6' [ym][loca][d][dataType] 2013-04 宜蘭縣 6 Temperature
# 第050號->花蓮縣 2013-04-10 >
# error '7' [ym][loca][d][dataType] 2013-04 花蓮縣 7 Temperature
# 第051號->花蓮縣 2013-04-15 >
# error '12' [ym][loca][d][dataType] 2013-04 花蓮縣 12 Temperature
# 第052號->宜蘭縣 2013-04-16 >
# error '13' [ym][loca][d][dataType] 2013-04 宜蘭縣 13 Temperature
# 第053號->宜蘭縣 2013-04-20 >
# error '17' [ym][loca][d][dataType] 2013-04 宜蘭縣 17 Temperature
# 第054號->臺東縣 2013-04-21 >
# 第055號->宜蘭縣 2013-04-21 >
# 第056號->花蓮縣 2013-05-03 >
# error '1' [ym][loca][d][dataType] 2013-05 花蓮縣 1 Temperature
# 第057號->臺東縣 2013-05-16 >
# error '13' [ym][loca][d][dataType] 2013-05 臺東縣 13 Temperature
# 第058號->臺東縣 2013-05-17 >
# 第059號->花蓮縣 2013-05-17 >
# error '14' [ym][loca][d][dataType] 2013-05 花蓮縣 14 Temperature
# 第060號->嘉義市 2013-05-18 >
# 第061號->宜蘭縣 2013-05-19 >
# error '16' [ym][loca][d][dataType] 2013-05 宜蘭縣 16 Temperature
# 第062號->花蓮縣 2013-05-20 >
# error '17' [ym][loca][d][dataType] 2013-05 花蓮縣 17 Temperature
# 第063號->花蓮縣 2013-05-21 >
# error '18' [ym][loca][d][dataType] 2013-05 花蓮縣 18 Temperature
# 第064號->花蓮縣 2013-05-21 >
# error '18' [ym][loca][d][dataType] 2013-05 花蓮縣 18 Temperature
# 第065號->花蓮縣 2013-05-21 >
# error '18' [ym][loca][d][dataType] 2013-05 花蓮縣 18 Temperature
# 第066號->花蓮縣 2013-05-21 >
# error '18' [ym][loca][d][dataType] 2013-05 花蓮縣 18 Temperature
# 第067號->花蓮縣 2013-05-21 >
# error '18' [ym][loca][d][dataType] 2013-05 花蓮縣 18 Temperature
# 第068號->花蓮縣 2013-05-21 >
# error '18' [ym][loca][d][dataType] 2013-05 花蓮縣 18 Temperature
# 第069號->花蓮縣 2013-05-21 >
# error '18' [ym][loca][d][dataType] 2013-05 花蓮縣 18 Temperature
# 第070號->花蓮縣 2013-05-21 >
# error '18' [ym][loca][d][dataType] 2013-05 花蓮縣 18 Temperature
# 第071號->花蓮縣 2013-05-23 >
# error '20' [ym][loca][d][dataType] 2013-05 花蓮縣 20 Temperature
# 第072號->宜蘭縣 2013-05-25 >
# 第073號->花蓮縣 2013-05-27 >
# error '24' [ym][loca][d][dataType] 2013-05 花蓮縣 24 Temperature
# 第074號->花蓮縣 2013-05-30 >
# error '1' [ym][loca][d][dataType] 2013-06 花蓮縣 1 Temperature
# 第075號->南投縣 2013-06-02 >
# 第076號->南投縣 2013-06-02 >
# 第077號->花蓮縣 2013-06-08 >
# error '5' [ym][loca][d][dataType] 2013-06 花蓮縣 5 Temperature
# 第078號->花蓮縣 2013-06-08 >
# error '5' [ym][loca][d][dataType] 2013-06 花蓮縣 5 Temperature
# 第079號->花蓮縣 2013-06-20 >
# error '17' [ym][loca][d][dataType] 2013-06 花蓮縣 17 Temperature
# 第080號->花蓮縣 2013-06-20 >
# error '17' [ym][loca][d][dataType] 2013-06 花蓮縣 17 Temperature
# 第081號->花蓮縣 2013-06-21 >
# error '18' [ym][loca][d][dataType] 2013-06 花蓮縣 18 Temperature
# 第082號->宜蘭縣 2013-06-26 >
# error '23' [ym][loca][d][dataType] 2013-06 宜蘭縣 23 Temperature
# 第083號->宜蘭縣 2013-06-29 >
# error '26' [ym][loca][d][dataType] 2013-06 宜蘭縣 26 Temperature
# 第084號->花蓮縣 2013-06-29 >
# error '1' [ym][loca][d][dataType] 2013-07 花蓮縣 1 Temperature
# 第085號->宜蘭縣 2013-07-03 >
# 第086號->臺東縣 2013-07-06 >
# error '3' [ym][loca][d][dataType] 2013-07 臺東縣 3 Temperature
# 第087號->花蓮縣 2013-07-11 >
# error '8' [ym][loca][d][dataType] 2013-07 花蓮縣 8 Temperature
# 第088號->臺東縣 2013-07-15 >
# error '12' [ym][loca][d][dataType] 2013-07 臺東縣 12 Temperature
# 第089號->花蓮縣 2013-07-15 >
# error '12' [ym][loca][d][dataType] 2013-07 花蓮縣 12 Temperature
# 第090號->花蓮縣 2013-07-16 >
# error '13' [ym][loca][d][dataType] 2013-07 花蓮縣 13 Temperature
# 第091號->花蓮縣 2013-07-21 >
# error '18' [ym][loca][d][dataType] 2013-07 花蓮縣 18 Temperature
# 第092號->臺中市 2013-07-23 >
# 第093號->花蓮縣 2013-07-24 >
# 第094號->花蓮縣 2013-07-24 >
# 第095號->花蓮縣 2013-07-24 >
# 第096號->臺東縣 2013-07-25 >
# 第097號->花蓮縣 2013-08-09 >
# error '6' [ym][loca][d][dataType] 2013-08 花蓮縣 6 Temperature
# 第098號->花蓮縣 2013-08-13 >
# error '10' [ym][loca][d][dataType] 2013-08 花蓮縣 10 Temperature
# 第099號->南投縣 2013-08-24 >
# 第100號->花蓮縣 2013-08-29 >
# error '26' [ym][loca][d][dataType] 2013-08 花蓮縣 26 Temperature
# 第101號->嘉義市 2013-09-01 >
# 第102號->嘉義市 2013-09-01 >
# 第103號->花蓮縣 2013-09-03 >
# error '1' [ym][loca][d][dataType] 2013-09 花蓮縣 1 Temperature
# 第104號->臺東縣 2013-09-05 >
# error '2' [ym][loca][d][dataType] 2013-09 臺東縣 2 Temperature
# 第105號->臺東縣 2013-09-06 >
# error '3' [ym][loca][d][dataType] 2013-09 臺東縣 3 Temperature
# 第106號->花蓮縣 2013-09-16 >
# error '13' [ym][loca][d][dataType] 2013-09 花蓮縣 13 Temperature
# 第107號->宜蘭縣 2013-09-18 >
# 第108號->臺東縣 2013-09-19 >
# 第109號->花蓮縣 2013-09-20 >
# 第110號->高雄市 2013-09-30 >
# 第111號->南投縣 2013-09-30 >
# 第112號->臺中市 2013-10-10 >
# 第113號->基隆市 2013-10-11 >
# 第114號->宜蘭縣 2013-10-15 >
# error '12' [ym][loca][d][dataType] 2013-10 宜蘭縣 12 Temperature
# 第115號->花蓮縣 2013-10-15 >
# error '12' [ym][loca][d][dataType] 2013-10 花蓮縣 12 Temperature
# 第116號->花蓮縣 2013-10-22 >
# error '19' [ym][loca][d][dataType] 2013-10 花蓮縣 19 Temperature
# 第117號->宜蘭縣 2013-10-22 >
# 第118號->花蓮縣 2013-10-25 >
# error '22' [ym][loca][d][dataType] 2013-10 花蓮縣 22 Temperature
# 第119號->花蓮縣 2013-10-27 >
# error '24' [ym][loca][d][dataType] 2013-10 花蓮縣 24 Temperature
# 第120號->澎湖縣 2013-10-28 >
# 第121號->花蓮縣 2013-10-31 >
# error '28' [ym][loca][d][dataType] 2013-10 花蓮縣 28 Temperature
# 第122號->花蓮縣 2013-10-31 >
# error '28' [ym][loca][d][dataType] 2013-10 花蓮縣 28 Temperature
# 第123號->花蓮縣 2013-10-31 >
# error '28' [ym][loca][d][dataType] 2013-10 花蓮縣 28 Temperature
# 第124號->花蓮縣 2013-10-31 >
# error '28' [ym][loca][d][dataType] 2013-10 花蓮縣 28 Temperature
# 第125號->花蓮縣 2013-10-31 >
# error '28' [ym][loca][d][dataType] 2013-10 花蓮縣 28 Temperature
# 第126號->花蓮縣 2013-11-01 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第127號->花蓮縣 2013-11-01 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第128號->花蓮縣 2013-11-01 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第129號->花蓮縣 2013-11-01 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第130號->花蓮縣 2013-11-01 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第131號->花蓮縣 2013-11-01 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第132號->花蓮縣 2013-11-01 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第133號->花蓮縣 2013-11-01 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第134號->花蓮縣 2013-11-01 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第135號->花蓮縣 2013-11-01 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第136號->花蓮縣 2013-11-02 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第137號->花蓮縣 2013-11-02 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第138號->花蓮縣 2013-11-02 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第139號->花蓮縣 2013-11-03 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第140號->花蓮縣 2013-11-04 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第141號->花蓮縣 2013-11-04 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第142號->花蓮縣 2013-11-04 >
# error '1' [ym][loca][d][dataType] 2013-11 花蓮縣 1 Temperature
# 第143號->嘉義市 2013-11-06 >
# 第144號->花蓮縣 2013-11-07 >
# error '4' [ym][loca][d][dataType] 2013-11 花蓮縣 4 Temperature
# 第145號->花蓮縣 2013-11-07 >
# error '4' [ym][loca][d][dataType] 2013-11 花蓮縣 4 Temperature
# 第146號->宜蘭縣 2013-11-11 >
# error '8' [ym][loca][d][dataType] 2013-11 宜蘭縣 8 Temperature
# 第147號->花蓮縣 2013-11-11 >
# error '8' [ym][loca][d][dataType] 2013-11 花蓮縣 8 Temperature
# 第148號->花蓮縣 2013-11-12 >
# error '9' [ym][loca][d][dataType] 2013-11 花蓮縣 9 Temperature
# 第149號->花蓮縣 2013-11-12 >
# error '9' [ym][loca][d][dataType] 2013-11 花蓮縣 9 Temperature
# 第150號->花蓮縣 2013-11-12 >
# error '9' [ym][loca][d][dataType] 2013-11 花蓮縣 9 Temperature
# 第151號->南投縣 2013-11-15 >
# 第152號->花蓮縣 2013-11-16 >
# error '13' [ym][loca][d][dataType] 2013-11 花蓮縣 13 Temperature
# 第153號->宜蘭縣 2013-11-21 >
# 第154號->花蓮縣 2013-11-24 >
# error '21' [ym][loca][d][dataType] 2013-11 花蓮縣 21 Temperature
# 第155號->花蓮縣 2013-11-24 >
# error '21' [ym][loca][d][dataType] 2013-11 花蓮縣 21 Temperature
# 第156號->花蓮縣 2013-11-24 >
# error '21' [ym][loca][d][dataType] 2013-11 花蓮縣 21 Temperature
# 第157號->花蓮縣 2013-11-26 >
# 第158號->臺東縣 2013-11-26 >
# 第159號->花蓮縣 2013-12-04 >
# error '1' [ym][loca][d][dataType] 2013-12 花蓮縣 1 Temperature
# 第160號->嘉義市 2013-12-15 >
# 第161號->宜蘭縣 2013-12-16 >
# error '13' [ym][loca][d][dataType] 2013-12 宜蘭縣 13 Temperature
# 第162號->花蓮縣 2013-12-18 >
# error '15' [ym][loca][d][dataType] 2013-12 花蓮縣 15 Temperature
# 第163號->宜蘭縣 2013-12-22 >
# 第164號->花蓮縣 2013-12-25 >
# 第165號->臺東縣 2013-12-25 >
# 第166號->花蓮縣 2013-12-25 >
# 2014
# 第001號->臺北市 2014-01-02 >
# error '30' [ym][loca][d][dataType] 2013-12 臺北市 30 Temperature
# 第002號->臺北市 2014-01-02 >
# error '30' [ym][loca][d][dataType] 2013-12 臺北市 30 Temperature
# 第003號->臺北市 2014-01-03 >
# 第004號->宜蘭縣 2014-01-09 >
# error '6' [ym][loca][d][dataType] 2014-01 宜蘭縣 6 Temperature
# 第005號->桃園市 2014-01-11 >
# 第006號->澎湖縣 2014-01-14 >
# 第007號->南投縣 2014-01-15 >
# error '12' [ym][loca][d][dataType] 2014-01 南投縣 12 Temperature
# 第008號->臺東縣 2014-01-15 >
# error '12' [ym][loca][d][dataType] 2014-01 臺東縣 12 Temperature
# 第009號->臺東縣 2014-01-15 >
# error '12' [ym][loca][d][dataType] 2014-01 臺東縣 12 Temperature
# 第010號->臺東縣 2014-01-15 >
# error '12' [ym][loca][d][dataType] 2014-01 臺東縣 12 Temperature
# 第011號->臺東縣 2014-01-15 >
# error '12' [ym][loca][d][dataType] 2014-01 臺東縣 12 Temperature
# 第012號->南投縣 2014-01-20 >
# 第013號->花蓮縣 2014-01-23 >
# error '20' [ym][loca][d][dataType] 2014-01 花蓮縣 20 Temperature
# 第014號->花蓮縣 2014-01-23 >
# error '20' [ym][loca][d][dataType] 2014-01 花蓮縣 20 Temperature
# 第015號->臺東縣 2014-01-24 >
# error '21' [ym][loca][d][dataType] 2014-01 臺東縣 21 Temperature
# 第016號->花蓮縣 2014-01-24 >
# error '21' [ym][loca][d][dataType] 2014-01 花蓮縣 21 Temperature
# 第017號->花蓮縣 2014-01-25 >
# error '22' [ym][loca][d][dataType] 2014-01 花蓮縣 22 Temperature
# 第018號->臺東縣 2014-01-29 >
# error '1' [ym][loca][d][dataType] 2014-02 臺東縣 1 Temperature
# 第019號->宜蘭縣 2014-02-01 >
# error '1' [ym][loca][d][dataType] 2014-02 宜蘭縣 1 Temperature
# 第020號->花蓮縣 2014-02-02 >
# error '1' [ym][loca][d][dataType] 2014-02 花蓮縣 1 Temperature
# 第021號->宜蘭縣 2014-02-07 >
# error '4' [ym][loca][d][dataType] 2014-02 宜蘭縣 4 Temperature
# 第022號->新竹縣 2014-02-08 >
# 第023號->宜蘭縣 2014-02-10 >
# error '7' [ym][loca][d][dataType] 2014-02 宜蘭縣 7 Temperature
# 第024號->臺北市 2014-02-12 >
# 第025號->臺東縣 2014-02-14 >
# error '11' [ym][loca][d][dataType] 2014-02 臺東縣 11 Temperature
# 第026號->花蓮縣 2014-02-15 >
# error '12' [ym][loca][d][dataType] 2014-02 花蓮縣 12 Temperature
# 第027號->臺東縣 2014-02-15 >
# 第028號->屏東縣 2014-02-16 >
# error '13' [ym][loca][d][dataType] 2014-02 屏東縣 13 Temperature
# 第029號->雲林縣 2014-02-17 >
# 第030號->宜蘭縣 2014-02-19 >
# error '16' [ym][loca][d][dataType] 2014-02 宜蘭縣 16 Temperature
# 第031號->屏東縣 2014-02-19 >
# 第032號->花蓮縣 2014-02-22 >
# error '19' [ym][loca][d][dataType] 2014-02 花蓮縣 19 Temperature
# 第033號->宜蘭縣 2014-02-22 >
# error '19' [ym][loca][d][dataType] 2014-02 宜蘭縣 19 Temperature
# 第034號->宜蘭縣 2014-02-22 >
# error '19' [ym][loca][d][dataType] 2014-02 宜蘭縣 19 Temperature
# 第035號->宜蘭縣 2014-02-27 >
# error '1' [ym][loca][d][dataType] 2014-03 宜蘭縣 1 Temperature
# 第036號->花蓮縣 2014-02-27 >
# error '1' [ym][loca][d][dataType] 2014-03 花蓮縣 1 Temperature
# 第037號->嘉義市 2014-03-05 >
# 第038號->花蓮縣 2014-03-07 >
# error '4' [ym][loca][d][dataType] 2014-03 花蓮縣 4 Temperature
# 第039號->彰化縣 2014-03-14 >
# 第040號->臺東縣 2014-03-16 >
# error '13' [ym][loca][d][dataType] 2014-03 臺東縣 13 Temperature
# 第041號->花蓮縣 2014-03-17 >
# error '14' [ym][loca][d][dataType] 2014-03 花蓮縣 14 Temperature
# 第042號->花蓮縣 2014-03-19 >
# error '16' [ym][loca][d][dataType] 2014-03 花蓮縣 16 Temperature
# 第043號->臺東縣 2014-03-21 >
# error '18' [ym][loca][d][dataType] 2014-03 臺東縣 18 Temperature
# 第044號->屏東縣 2014-03-22 >
# 第045號->宜蘭縣 2014-03-25 >
# 第046號->臺東縣 2014-03-26 >
# error '23' [ym][loca][d][dataType] 2014-03 臺東縣 23 Temperature
# 第047號->臺東縣 2014-03-26 >
# error '23' [ym][loca][d][dataType] 2014-03 臺東縣 23 Temperature
# 第048號->臺東縣 2014-03-27 >
# 第049號->花蓮縣 2014-03-27 >
# error '24' [ym][loca][d][dataType] 2014-03 花蓮縣 24 Temperature
# 第050號->臺東縣 2014-03-27 >
# 第051號->花蓮縣 2014-03-27 >
# error '24' [ym][loca][d][dataType] 2014-03 花蓮縣 24 Temperature
# 第052號->花蓮縣 2014-03-29 >
# error '1' [ym][loca][d][dataType] 2014-04 花蓮縣 1 Temperature
# 第053號->花蓮縣 2014-03-29 >
# error '1' [ym][loca][d][dataType] 2014-04 花蓮縣 1 Temperature
# 第054號->南投縣 2014-04-01 >
# 第055號->花蓮縣 2014-04-10 >
# error '7' [ym][loca][d][dataType] 2014-04 花蓮縣 7 Temperature
# 第056號->宜蘭縣 2014-04-16 >
# error '13' [ym][loca][d][dataType] 2014-04 宜蘭縣 13 Temperature
# 第057號->宜蘭縣 2014-04-19 >
# error '16' [ym][loca][d][dataType] 2014-04 宜蘭縣 16 Temperature
# 第058號->宜蘭縣 2014-04-19 >
# error '16' [ym][loca][d][dataType] 2014-04 宜蘭縣 16 Temperature
# 第059號->宜蘭縣 2014-04-21 >
# 第060號->花蓮縣 2014-04-26 >
# 第061號->臺南市 2014-05-02 >
# error '1' [ym][loca][d][dataType] 2014-05 臺南市 1 Temperature
# 第062號->花蓮縣 2014-05-04 >
# error '1' [ym][loca][d][dataType] 2014-05 花蓮縣 1 Temperature
# 第063號->花蓮縣 2014-05-04 >
# error '1' [ym][loca][d][dataType] 2014-05 花蓮縣 1 Temperature
# 第064號->花蓮縣 2014-05-04 >
# error '1' [ym][loca][d][dataType] 2014-05 花蓮縣 1 Temperature
# 第065號->花蓮縣 2014-05-04 >
# error '1' [ym][loca][d][dataType] 2014-05 花蓮縣 1 Temperature
# 第066號->嘉義市 2014-05-11 >
# 第067號->臺南市 2014-05-16 >
# 第068號->花蓮縣 2014-05-17 >
# error '14' [ym][loca][d][dataType] 2014-05 花蓮縣 14 Temperature
# 第069號->宜蘭縣 2014-05-18 >
# error '15' [ym][loca][d][dataType] 2014-05 宜蘭縣 15 Temperature
# 第070號->花蓮縣 2014-05-21 >
# error '18' [ym][loca][d][dataType] 2014-05 花蓮縣 18 Temperature
# 第071號->花蓮縣 2014-05-21 >
# error '18' [ym][loca][d][dataType] 2014-05 花蓮縣 18 Temperature
# 第072號->花蓮縣 2014-05-24 >
# 第073號->宜蘭縣 2014-05-24 >
# error '21' [ym][loca][d][dataType] 2014-05 宜蘭縣 21 Temperature
# 第074號->宜蘭縣 2014-05-24 >
# error '21' [ym][loca][d][dataType] 2014-05 宜蘭縣 21 Temperature
# 第075號->臺東縣 2014-05-25 >
# error '22' [ym][loca][d][dataType] 2014-05 臺東縣 22 Temperature
# 第076號->臺東縣 2014-05-28 >
# error '25' [ym][loca][d][dataType] 2014-05 臺東縣 25 Temperature
# 第077號->臺東縣 2014-05-29 >
# error '26' [ym][loca][d][dataType] 2014-05 臺東縣 26 Temperature
# 第078號->臺東縣 2014-05-31 >
# 第079號->新竹縣 2014-05-31 >
# 第080號->宜蘭縣 2014-05-31 >
# error '1' [ym][loca][d][dataType] 2014-06 宜蘭縣 1 Temperature
# 第081號->花蓮縣 2014-06-06 >
# error '3' [ym][loca][d][dataType] 2014-06 花蓮縣 3 Temperature
# 第082號->花蓮縣 2014-06-15 >
# error '12' [ym][loca][d][dataType] 2014-06 花蓮縣 12 Temperature
# 第083號->花蓮縣 2014-06-15 >
# error '12' [ym][loca][d][dataType] 2014-06 花蓮縣 12 Temperature
# 第084號->宜蘭縣 2014-06-18 >
# error '15' [ym][loca][d][dataType] 2014-06 宜蘭縣 15 Temperature
# 第085號->花蓮縣 2014-06-18 >
# error '15' [ym][loca][d][dataType] 2014-06 花蓮縣 15 Temperature
# 第086號->臺中市 2014-06-19 >
# 第087號->嘉義市 2014-06-20 >
# 第088號->花蓮縣 2014-06-21 >
# error '18' [ym][loca][d][dataType] 2014-06 花蓮縣 18 Temperature
# 第089號->宜蘭縣 2014-06-22 >
# error '19' [ym][loca][d][dataType] 2014-06 宜蘭縣 19 Temperature
# 第090號->花蓮縣 2014-06-22 >
# error '19' [ym][loca][d][dataType] 2014-06 花蓮縣 19 Temperature
# 第091號->花蓮縣 2014-06-26 >
# 第092號->宜蘭縣 2014-07-02 >
# error '1' [ym][loca][d][dataType] 2014-07 宜蘭縣 1 Temperature
# 第093號->宜蘭縣 2014-07-13 >
# error '10' [ym][loca][d][dataType] 2014-07 宜蘭縣 10 Temperature
# 第094號->南投縣 2014-07-14 >
# 第095號->臺東縣 2014-07-17 >
# error '14' [ym][loca][d][dataType] 2014-07 臺東縣 14 Temperature
# 第096號->嘉義市 2014-07-22 >
# error '19' [ym][loca][d][dataType] 2014-07 嘉義市 19 Temperature
# 第097號->宜蘭縣 2014-07-26 >
# error '23' [ym][loca][d][dataType] 2014-07 宜蘭縣 23 Temperature
# 第098號->嘉義市 2014-07-26 >
# 第099號->花蓮縣 2014-07-28 >
# 第100號->臺東縣 2014-07-31 >
# error '28' [ym][loca][d][dataType] 2014-07 臺東縣 28 Temperature
# 第101號->臺東縣 2014-08-01 >
# error '1' [ym][loca][d][dataType] 2014-08 臺東縣 1 Temperature
# 第102號->宜蘭縣 2014-08-01 >
# error '1' [ym][loca][d][dataType] 2014-08 宜蘭縣 1 Temperature
# 第103號->臺中市 2014-08-02 >
# 第104號->臺東縣 2014-08-06 >
# 第105號->花蓮縣 2014-08-09 >
# 第106號->嘉義市 2014-08-12 >
# error '9' [ym][loca][d][dataType] 2014-08 嘉義市 9 Temperature
# 第107號->宜蘭縣 2014-08-21 >
# 第108號->嘉義市 2014-08-27 >
# 第109號->嘉義市 2014-09-04 >
# 第110號->花蓮縣 2014-09-05 >
# error '2' [ym][loca][d][dataType] 2014-09 花蓮縣 2 Temperature
# 第111號->宜蘭縣 2014-09-10 >
# 第112號->花蓮縣 2014-09-21 >
# error '18' [ym][loca][d][dataType] 2014-09 花蓮縣 18 Temperature
# 第113號->花蓮縣 2014-09-24 >
# error '21' [ym][loca][d][dataType] 2014-09 花蓮縣 21 Temperature
# 第114號->花蓮縣 2014-09-24 >
# error '21' [ym][loca][d][dataType] 2014-09 花蓮縣 21 Temperature
# 第115號->臺東縣 2014-09-25 >
# 第116號->苗栗縣 2014-09-25 >
# 第117號->花蓮縣 2014-09-26 >
# error '23' [ym][loca][d][dataType] 2014-09 花蓮縣 23 Temperature
# 第118號->花蓮縣 2014-09-26 >
# error '23' [ym][loca][d][dataType] 2014-09 花蓮縣 23 Temperature
# 第119號->花蓮縣 2014-09-29 >
# error '1' [ym][loca][d][dataType] 2014-10 花蓮縣 1 Temperature
# 第120號->花蓮縣 2014-09-29 >
# error '1' [ym][loca][d][dataType] 2014-10 花蓮縣 1 Temperature
# 第121號->花蓮縣 2014-10-08 >
# 第122號->宜蘭縣 2014-10-09 >
# error '6' [ym][loca][d][dataType] 2014-10 宜蘭縣 6 Temperature
# 第123號->宜蘭縣 2014-10-10 >
# error '7' [ym][loca][d][dataType] 2014-10 宜蘭縣 7 Temperature
# 第124號->高雄市 2014-10-12 >
# error '9' [ym][loca][d][dataType] 2014-10 高雄市 9 Temperature
# 第125號->高雄市 2014-10-13 >
# 第126號->雲林縣 2014-10-23 >
# 第127號->宜蘭縣 2014-10-26 >
# 第128號->嘉義縣 2014-10-29 >
# 第129號->花蓮縣 2014-11-01 >
# not in
# 第130號->臺南市 2014-11-04 >
# not in
# 第131號->雲林縣 2014-11-12 >
# not in
# 第132號->臺中市 2014-11-15 >
# not in
# 第133號->花蓮縣 2014-11-15 >
# not in
# 第134號->臺南市 2014-11-16 >
# not in
# 第135號->花蓮縣 2014-11-16 >
# not in
# 第136號->花蓮縣 2014-11-16 >
# not in
# 第137號->花蓮縣 2014-11-17 >
# not in
# 第138號->花蓮縣 2014-11-18 >
# not in
# 第139號->宜蘭縣 2014-11-20 >
# not in
# 第140號->宜蘭縣 2014-11-20 >
# not in
# 第141號->宜蘭縣 2014-11-20 >
# not in
# 第142號->高雄市 2014-11-21 >
# not in
# 第143號->宜蘭縣 2014-11-30 >
# not in
# 第144號->宜蘭縣 2014-11-30 >
# not in
# 第145號->宜蘭縣 2014-12-02 >
# error '2014-12' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第146號->花蓮縣 2014-12-04 >
# error '2014-12' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第147號->宜蘭縣 2014-12-09 >
# error '2014-12' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第148號->基隆市 2014-12-11 >
# error '2014-12' [ym][loca][d][dataType] 2014-11 基隆市 1 StnPres
# 第149號->臺東縣 2014-12-14 >
# error '2014-12' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第150號->臺中市 2014-12-15 >
# error '2014-12' [ym][loca][d][dataType] 2014-11 臺中市 1 StnPres
# 第151號->宜蘭縣 2014-12-22 >
# error '2014-12' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第152號->花蓮縣 2014-12-28 >
# error '2014-12' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第153號->宜蘭縣 2014-12-31 >
# error '2014-12' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第154號->宜蘭縣 2014-12-31 >
# error '2014-12' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 2015
# 第001號->花蓮縣 2015-01-02 >
# error '2015-01' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第002號->宜蘭縣 2015-01-05 >
# error '2015-01' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第003號->花蓮縣 2015-01-07 >
# error '2015-01' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第004號->花蓮縣 2015-01-16 >
# error '2015-01' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# ...
# error '2015-12' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第088號->花蓮縣 2015-12-02 >
# error '2015-12' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第089號->宜蘭縣 2015-12-03 >
# error '2015-12' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第090號->臺東縣 2015-12-03 >
# error '2015-12' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第091號->花蓮縣 2015-12-06 >
# error '2015-12' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第092號->臺東縣 2015-12-12 >
# error '2015-12' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第093號->臺東縣 2015-12-12 >
# error '2015-12' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第094號->花蓮縣 2015-12-14 >
# error '2015-12' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第095號->花蓮縣 2015-12-22 >
# error '2015-12' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第096號->南投縣 2015-12-25 >
# error '2015-12' [ym][loca][d][dataType] 2014-11 南投縣 1 StnPres
# 第097號->臺中市 2015-12-25 >
# error '2015-12' [ym][loca][d][dataType] 2014-11 臺中市 1 StnPres
# 第098號->新竹縣 2015-12-26 >
# error '2015-12' [ym][loca][d][dataType] 2014-11 新竹縣 1 StnPres
# 第099號->花蓮縣 2015-12-26 >
# error '2015-12' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第100號->臺東縣 2015-12-31 >
# error '2015-12' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 2016
# 第001號->花蓮縣 2016-01-02 >
# error '2016-01' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第002號->宜蘭縣 2016-01-03 >
# error '2016-01' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第003號->花蓮縣 2016-01-11 >
# error '2016-01' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第004號->臺東縣 2016-01-19 >
# error '2016-01' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第005號->基隆市 2016-02-02 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 基隆市 1 StnPres
# 第006號->屏東縣 2016-02-06 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 屏東縣 1 StnPres
# 第007號->臺南市 2016-02-06 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 臺南市 1 StnPres
# 第008號->臺南市 2016-02-06 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 臺南市 1 StnPres
# 第009號->臺南市 2016-02-06 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 臺南市 1 StnPres
# 第010號->臺南市 2016-02-06 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 臺南市 1 StnPres
# 第011號->花蓮縣 2016-02-09 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第012號->苗栗縣 2016-02-14 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 苗栗縣 1 StnPres
# 第013號->臺東縣 2016-02-16 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第014號->臺東縣 2016-02-18 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第015號->臺東縣 2016-02-18 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第016號->花蓮縣 2016-02-19 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第017號->臺南市 2016-02-19 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 臺南市 1 StnPres
# 第018號->臺東縣 2016-02-27 >
# error '2016-02' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第019號->花蓮縣 2016-03-01 >
# error '2016-03' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第020號->臺南市 2016-03-02 >
# error '2016-03' [ym][loca][d][dataType] 2014-11 臺南市 1 StnPres
# 第021號->宜蘭縣 2016-03-06 >
# error '2016-03' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第022號->臺東縣 2016-03-22 >
# error '2016-03' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第023號->宜蘭縣 2016-04-11 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第024號->花蓮縣 2016-04-12 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第025號->臺東縣 2016-04-16 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第026號->臺東縣 2016-04-18 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第027號->臺南市 2016-04-19 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 臺南市 1 StnPres
# 第028號->臺東縣 2016-04-25 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第029號->花蓮縣 2016-04-25 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第030號->花蓮縣 2016-04-26 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第031號->花蓮縣 2016-04-27 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第032號->花蓮縣 2016-04-27 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第033號->花蓮縣 2016-04-27 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第034號->花蓮縣 2016-04-27 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第035號->花蓮縣 2016-04-28 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第036號->花蓮縣 2016-04-28 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第037號->花蓮縣 2016-04-28 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第038號->花蓮縣 2016-04-28 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第039號->花蓮縣 2016-04-28 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第040號->臺東縣 2016-04-28 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第041號->花蓮縣 2016-04-28 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第042號->花蓮縣 2016-04-28 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第043號->花蓮縣 2016-04-28 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第044號->宜蘭縣 2016-04-28 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第045號->花蓮縣 2016-04-29 >
# error '2016-04' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第046號->花蓮縣 2016-05-01 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第047號->花蓮縣 2016-05-01 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第048號->臺東縣 2016-05-02 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第049號->花蓮縣 2016-05-02 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第050號->花蓮縣 2016-05-02 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第051號->花蓮縣 2016-05-03 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第052號->花蓮縣 2016-05-03 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第053號->花蓮縣 2016-05-06 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第054號->臺東縣 2016-05-07 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第055號->花蓮縣 2016-05-07 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第056號->花蓮縣 2016-05-07 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第057號->南投縣 2016-05-08 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 南投縣 1 StnPres
# 第058號->花蓮縣 2016-05-09 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第059號->臺東縣 2016-05-12 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第060號->宜蘭縣 2016-05-12 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第061號->宜蘭縣 2016-05-12 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第062號->宜蘭縣 2016-05-12 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第063號->宜蘭縣 2016-05-12 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第064號->宜蘭縣 2016-05-13 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第065號->宜蘭縣 2016-05-13 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第066號->花蓮縣 2016-05-13 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第067號->花蓮縣 2016-05-14 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第068號->花蓮縣 2016-05-14 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第069號->花蓮縣 2016-05-14 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第070號->臺東縣 2016-05-18 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第071號->花蓮縣 2016-05-21 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第072號->屏東縣 2016-05-22 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 屏東縣 1 StnPres
# 第073號->屏東縣 2016-05-22 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 屏東縣 1 StnPres
# 第074號->花蓮縣 2016-05-26 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第075號->臺東縣 2016-05-30 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第076號->花蓮縣 2016-05-30 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第077號->基隆市 2016-05-31 >
# error '2016-05' [ym][loca][d][dataType] 2014-11 基隆市 1 StnPres
# 第078號->花蓮縣 2016-06-14 >
# error '2016-06' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第079號->臺東縣 2016-06-19 >
# error '2016-06' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第080號->臺東縣 2016-06-20 >
# error '2016-06' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第081號->宜蘭縣 2016-06-20 >
# error '2016-06' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第082號->花蓮縣 2016-06-24 >
# error '2016-06' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第083號->花蓮縣 2016-06-29 >
# error '2016-06' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第084號->臺東縣 2016-07-14 >
# error '2016-07' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第085號->新竹市 2016-07-16 >
# error '2016-07' [ym][loca][d][dataType] 2014-11 新竹市 1 StnPres
# 第086號->宜蘭縣 2016-07-16 >
# error '2016-07' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第087號->臺中市 2016-07-20 >
# error '2016-07' [ym][loca][d][dataType] 2014-11 臺中市 1 StnPres
# 第088號->花蓮縣 2016-07-27 >
# error '2016-07' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第089號->花蓮縣 2016-08-04 >
# error '2016-08' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第090號->花蓮縣 2016-08-25 >
# error '2016-08' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第091號->宜蘭縣 2016-09-01 >
# error '2016-09' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第092號->宜蘭縣 2016-09-05 >
# error '2016-09' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第093號->花蓮縣 2016-09-24 >
# error '2016-09' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第094號->宜蘭縣 2016-09-28 >
# error '2016-09' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第095號->臺南市 2016-09-30 >
# error '2016-09' [ym][loca][d][dataType] 2014-11 臺南市 1 StnPres
# 第096號->臺東縣 2016-10-04 >
# error '2016-10' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第097號->臺東縣 2016-10-06 >
# error '2016-10' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第098號->臺東縣 2016-10-25 >
# error '2016-10' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第099號->花蓮縣 2016-10-29 >
# error '2016-10' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第100號->嘉義市 2016-11-07 >
# error '2016-11' [ym][loca][d][dataType] 2014-11 嘉義市 1 StnPres
# 第101號->臺東縣 2016-11-07 >
# error '2016-11' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第102號->花蓮縣 2016-11-12 >
# error '2016-11' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第103號->嘉義市 2016-11-21 >
# error '2016-11' [ym][loca][d][dataType] 2014-11 嘉義市 1 StnPres
# 第104號->花蓮縣 2016-11-25 >
# error '2016-11' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第105號->臺南市 2016-11-28 >
# error '2016-11' [ym][loca][d][dataType] 2014-11 臺南市 1 StnPres
# 第106號->臺東縣 2016-11-30 >
# error '2016-11' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第107號->花蓮縣 2016-12-04 >
# error '2016-12' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第108號->宜蘭縣 2016-12-09 >
# error '2016-12' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第109號->臺東縣 2016-12-15 >
# error '2016-12' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第110號->臺東縣 2016-12-16 >
# error '2016-12' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第111號->花蓮縣 2016-12-25 >
# error '2016-12' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第112號->宜蘭縣 2016-12-30 >
# error '2016-12' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 2017
# 第001號->臺東縣 2017-01-03 >
# error '2017-01' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第002號->嘉義市 2017-01-04 >
# error '2017-01' [ym][loca][d][dataType] 2014-11 嘉義市 1 StnPres
# 第003號->花蓮縣 2017-01-04 >
# error '2017-01' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第004號->臺東縣 2017-01-08 >
# error '2017-01' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第005號->嘉義市 2017-01-12 >
# error '2017-01' [ym][loca][d][dataType] 2014-11 嘉義市 1 StnPres
# 第006號->嘉義市 2017-01-13 >
# error '2017-01' [ym][loca][d][dataType] 2014-11 嘉義市 1 StnPres
# 第007號->花蓮縣 2017-01-25 >
# error '2017-01' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第008號->臺南市 2017-02-11 >
# error '2017-02' [ym][loca][d][dataType] 2014-11 臺南市 1 StnPres
# 第009號->臺南市 2017-02-11 >
# error '2017-02' [ym][loca][d][dataType] 2014-11 臺南市 1 StnPres
# 第010號->臺南市 2017-02-12 >
# error '2017-02' [ym][loca][d][dataType] 2014-11 臺南市 1 StnPres
# 第011號->花蓮縣 2017-02-22 >
# error '2017-02' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第012號->宜蘭縣 2017-02-28 >
# error '2017-02' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第013號->宜蘭縣 2017-03-04 >
# error '2017-03' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第014號->宜蘭縣 2017-03-08 >
# error '2017-03' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第015號->宜蘭縣 2017-03-20 >
# error '2017-03' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第016號->嘉義市 2017-03-24 >
# error '2017-03' [ym][loca][d][dataType] 2014-11 嘉義市 1 StnPres
# 第017號->嘉義市 2017-03-25 >
# error '2017-03' [ym][loca][d][dataType] 2014-11 嘉義市 1 StnPres
# 第018號->臺東縣 2017-03-30 >
# error '2017-03' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第019號->嘉義市 2017-04-17 >
# error '2017-04' [ym][loca][d][dataType] 2014-11 嘉義市 1 StnPres
# 第020號->臺東縣 2017-04-30 >
# error '2017-04' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第021號->花蓮縣 2017-05-05 >
# error '2017-05' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第022號->臺東縣 2017-05-16 >
# error '2017-05' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第023號->嘉義市 2017-05-24 >
# error '2017-05' [ym][loca][d][dataType] 2014-11 嘉義市 1 StnPres
# 第024號->嘉義市 2017-05-24 >
# error '2017-05' [ym][loca][d][dataType] 2014-11 嘉義市 1 StnPres
# 第025號->嘉義市 2017-05-25 >
# error '2017-05' [ym][loca][d][dataType] 2014-11 嘉義市 1 StnPres
# 第026號->宜蘭縣 2017-06-04 >
# error '2017-06' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第027號->宜蘭縣 2017-06-11 >
# error '2017-06' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第028號->高雄市 2017-06-16 >
# error '2017-06' [ym][loca][d][dataType] 2014-11 高雄市 1 StnPres
# 第029號->宜蘭縣 2017-06-21 >
# error '2017-06' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第030號->臺南市 2017-06-22 >
# error '2017-06' [ym][loca][d][dataType] 2014-11 臺南市 1 StnPres
# 第031號->花蓮縣 2017-06-26 >
# error '2017-06' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第032號->宜蘭縣 2017-07-02 >
# error '2017-07' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第033號->花蓮縣 2017-07-18 >
# error '2017-07' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第034號->嘉義市 2017-07-30 >
# error '2017-07' [ym][loca][d][dataType] 2014-11 嘉義市 1 StnPres
# 第035號->花蓮縣 2017-08-10 >
# error '2017-08' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第036號->臺東縣 2017-08-11 >
# error '2017-08' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第037號->屏東縣 2017-09-04 >
# error '2017-09' [ym][loca][d][dataType] 2014-11 屏東縣 1 StnPres
# 第038號->花蓮縣 2017-09-05 >
# error '2017-09' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第039號->臺東縣 2017-09-06 >
# error '2017-09' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第040號->宜蘭縣 2017-09-11 >
# error '2017-09' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第041號->花蓮縣 2017-09-18 >
# error '2017-09' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第042號->花蓮縣 2017-09-20 >
# error '2017-09' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第043號->嘉義市 2017-10-26 >
# error '2017-10' [ym][loca][d][dataType] 2014-11 嘉義市 1 StnPres
# 第044號->南投縣 2017-10-30 >
# error '2017-10' [ym][loca][d][dataType] 2014-11 南投縣 1 StnPres
# 第045號->臺東縣 2017-11-03 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第046號->臺東縣 2017-11-03 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 臺東縣 1 StnPres
# 第047號->花蓮縣 2017-11-04 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 花蓮縣 1 StnPres
# 第048號->雲林縣 2017-11-07 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 雲林縣 1 StnPres
# 第049號->雲林縣 2017-11-11 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 雲林縣 1 StnPres
# 第050號->雲林縣 2017-11-11 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 雲林縣 1 StnPres
# 第051號->雲林縣 2017-11-11 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 雲林縣 1 StnPres
# 第052號->雲林縣 2017-11-11 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 雲林縣 1 StnPres
# 第053號->雲林縣 2017-11-11 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 雲林縣 1 StnPres
# 第054號->宜蘭縣 2017-11-12 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第055號->雲林縣 2017-11-22 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 雲林縣 1 StnPres
# 第056號->雲林縣 2017-11-23 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 雲林縣 1 StnPres
# 第057號->雲林縣 2017-11-24 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 雲林縣 1 StnPres
# 第058號->雲林縣 2017-11-27 >
# error '2017-11' [ym][loca][d][dataType] 2014-11 雲林縣 1 StnPres
# 第059號->宜蘭縣 2017-12-08 >
# error '2017-12' [ym][loca][d][dataType] 2014-11 宜蘭縣 1 StnPres
# 第060號->雲林縣 2017-12-24 >
# error '2017-12' [ym][loca][d][dataType] 2014-11 雲林縣 1 StnPres

# %%
specificWeatherDataDict["2013-10"]["基隆市"]

# %%
deltaDict
# Out:
# {'2011': {'第001號': {},
#   '第002號': {},
#   '第003號': {},
#   '第004號': {'Precp_delta': 4.766666666666668,
#    'RH_delta': -0.6666666666666572,
#    'StnPres_delta': 6.033333333333417,
#    'Temperature_delta': -2.4333333333333353},
#   '第005號': {'Precp_delta': 0.0,
#    'RH_delta': 1.0,
#    'StnPres_delta': 1.7333333333332348,
#    'Temperature_delta': 1.4666666666666668},
#   '第006號': {'Precp_delta': 0.0,
#    'RH_delta': 0.6666666666666714,
#    'StnPres_delta': 2.300000000000068,
#    'Temperature_delta': 0.09999999999999964},
#   '第007號': {'Precp_delta': 0.0,
#    'RH_delta': -6.0,
#    'StnPres_delta': 0.5666666666667197,
#    'Temperature_delta': -2.466666666666665},
#   '第008號': {},
#   '第009號': {},
#   '第010號': {},
#   '第011號': {'Precp_delta': -0.26666666666666666,
#    'RH_delta': -4.0,
#    'StnPres_delta': -5.333333333333371,
#    'Temperature_delta': 0.8999999999999986},
#   '第012號': {},
#   '第013號': {},
#   '第014號': {},
#   '第015號': {},
#   '第016號': {'Precp_delta': 0.0,
#    'RH_delta': 6.666666666666671,
#    'StnPres_delta': -1.8666666666666742,
#    'Temperature_delta': -0.8000000000000043},
#   '第017號': {'Precp_delta': 0.33333333333333326,
#    'RH_delta': 31.33333333333333,
#    'StnPres_delta': -0.7000000000000455,
#    'Temperature_delta': -3.133333333333333},
#   '第018號': {},
#   '第019號': {},
#   '第020號': {},
#   '第021號': {},
#   '第022號': {},
#   '第023號': {'Precp_delta': -0.16666666666666666,
#    'RH_delta': 0.0,
#    'StnPres_delta': 0.0,
#    'Temperature_delta': 3.700000000000001},
#   '第024號': {'Precp_delta': -0.16666666666666666,
#    'RH_delta': 0.0,
#    'StnPres_delta': 0.0,
#    'Temperature_delta': 3.700000000000001},
#   '第025號': {},
#   '第026號': {},
#   '第027號': {},
#   '第028號': {},
#   '第029號': {},
#   '第030號': {},
#   '第031號': {},
#   '第032號': {'Precp_delta': 0.16666666666666666,
#    'RH_delta': -10.0,
#    'StnPres_delta': 3.8999999999998636,
#    'Temperature_delta': -2.633333333333333},
#   '第033號': {},
#   '第034號': {'Precp_delta': 11.16666666666667,
#    'RH_delta': -4.666666666666671,
#    'StnPres_delta': -0.6999999999999318,
#    'Temperature_delta': 1.700000000000001},
#   '第035號': {},
#   '第036號': {},
#   '第037號': {},
#   '第038號': {},
#   '第039號': {},
#   '第040號': {},
#   '第041號': {},
#   '第042號': {'Precp_delta': 0.0,
#    'RH_delta': 0.0,
#    'StnPres_delta': 0.0,
#    'Temperature_delta': -0.56666666666667},
#   '第043號': {'Precp_delta': 0.0,
#    'RH_delta': -6.666666666666671,
#    'StnPres_delta': -2.533333333333303,
#    'Temperature_delta': -0.06666666666666288},
#   '第044號': {},
#   '第045號': {},
#   '第046號': {},
#   '第047號': {},
#   '第048號': {'Precp_delta': 0.16666666666666666,
#    'RH_delta': 8.333333333333343,
#    'StnPres_delta': -0.533333333333303,
#    'Temperature_delta': 1.033333333333335},
#   '第049號': {},
#   '第050號': {},
#   '第051號': {},
#   '第052號': {'Precp_delta': -0.033333333333333326,
#    'RH_delta': 7.333333333333329,
#    'StnPres_delta': -2.2737367544323206e-13,
#    'Temperature_delta': -1.4666666666666668},
#   '第053號': {},
#   '第054號': {},
#   '第055號': {},
#   '第056號': {},
#   '第057號': {'Precp_delta': 0.0,
#    'RH_delta': -3.0,
#    'StnPres_delta': -3.3999999999998636,
#    'Temperature_delta': 1.8333333333333321},
#   '第058號': {},
#   '第059號': {},
#   '第060號': {},
#   '第061號': {'Precp_delta': 4.3,
#    'RH_delta': 5.666666666666657,
#    'StnPres_delta': 0.5666666666667197,
#    'Temperature_delta': 1.2666666666666666},
#   '第062號': {'Precp_delta': 4.3,
#    'RH_delta': 5.666666666666657,
#    'StnPres_delta': 0.5666666666667197,
#    'Temperature_delta': 1.2666666666666666},
#   '第063號': {'Precp_delta': 68.39999999999999,
#    'RH_delta': 7.0,
#    'StnPres_delta': 0.900000000000091,
#    'Temperature_delta': -1.6999999999999957},
#   '第064號': {'Precp_delta': 23.333333333333336,
#    'RH_delta': 2.6666666666666714,
#    'StnPres_delta': -2.633333333333212,
#    'Temperature_delta': -0.09999999999999787},
#   '第065號': {},
#   '第066號': {},
#   '第067號': {'Precp_delta': -0.5,
#    'RH_delta': 0.0,
#    'StnPres_delta': 0.0,
#    'Temperature_delta': 1.6666666666666714},
#   '第068號': {},
#   '第069號': {},
#   '第070號': {},
#   '第071號': {},
#   '第072號': {},
#   '第073號': {},
#   '第074號': {},
#   '第075號': {},
#   '第076號': {},
#   '第077號': {},
#   '第078號': {},
#   '第079號': {'Precp_delta': -46.333333333333336,
#    'RH_delta': 4.333333333333329,
#    'StnPres_delta': 4.666666666666629,
#    'Temperature_delta': 0.16666666666666696},
#   '第080號': {'Precp_delta': -33.5,
#    'RH_delta': -9.666666666666657,
#    'StnPres_delta': 0.933333333333394,
#    'Temperature_delta': 2.5},
#   '第081號': {},
#   '第082號': {},
#   '第083號': {},
#   '第084號': {},
#   '第085號': {},
#   '第086號': {},
#   '第087號': {},
#   '第088號': {},
#   '第089號': {},
#   '第090號': {},
#   '第091號': {},
#   '第092號': {},
#   '第093號': {},
#   '第094號': {},
#   '第095號': {},
#   '第096號': {},
#   '第097號': {},
#   '第098號': {},
#   '第099號': {},
#   '第100號': {},
#   '第101號': {},
#   '第102號': {},
#   '第103號': {},
#   '第104號': {'Precp_delta': 8.333333333333332,
#    'RH_delta': -4.0,
#    'StnPres_delta': -6.033333333333417,
#    'Temperature_delta': 1.399999999999995},
#   '第105號': {},
#   '第106號': {},
#   '第107號': {},
#   '第108號': {},
#   '第109號': {},
#   '第110號': {},
#   '第111號': {},
#   '第112號': {},
#   '第113號': {},
#   '第114號': {'Precp_delta': -27.0,
#    'RH_delta': -7.333333333333343,
#    'StnPres_delta': 5.866666666666788,
#    'Temperature_delta': 1.7999999999999972},
#   '第115號': {'Precp_delta': 17.5,
#    'RH_delta': 1.3333333333333286,
#    'StnPres_delta': 0.3000000000001819,
#    'Temperature_delta': -0.4000000000000057},
#   '第116號': {},
#   '第117號': {'Precp_delta': -1.4333333333333333,
#    'RH_delta': -1.6666666666666714,
#    'StnPres_delta': -2.9666666666665833,
#    'Temperature_delta': -1.0},
#   '第118號': {'Precp_delta': nan,
#    'RH_delta': nan,
#    'StnPres_delta': nan,
#    'Temperature_delta': nan},
#   '第119號': {},
#   '第120號': {'Precp_delta': nan,
#    'RH_delta': nan,
#    'StnPres_delta': nan,
#    'Temperature_delta': nan},
#   '第121號': {'Precp_delta': 2.8666666666666667,
#    'RH_delta': 1.6666666666666714,
#    'StnPres_delta': 4.633333333333326,
#    'Temperature_delta': 0.3333333333333339},
#   '第122號': {},
#   '第123號': {},
#   '第124號': {},
#   '第125號': {},
#   '第126號': {'Precp_delta': 11.666666666666666,
#    'RH_delta': 12.666666666666671,
#    'StnPres_delta': -7.7000000000000455,
#    'Temperature_delta': -1.7666666666666622},
#   '第127號': {},
#   '第128號': {},
#   '第129號': {'Precp_delta': 0.7000000000000001,
#    'RH_delta': -1.0,
#    'StnPres_delta': 2.8999999999999773,
#    'Temperature_delta': 1.3333333333333321},
#   '第130號': {'Precp_delta': 0.7000000000000001,
#    'RH_delta': -1.0,
#    'StnPres_delta': 2.8999999999999773,
#    'Temperature_delta': 1.3333333333333321},
#   '第131號': {'Precp_delta': 0.7000000000000001,
#    'RH_delta': -1.0,
#    'StnPres_delta': 2.8999999999999773,
#    'Temperature_delta': 1.3333333333333321},
#   '第132號': {},
#   '第133號': {'Precp_delta': -7.333333333333333,
#    'RH_delta': -3.6666666666666714,
#    'StnPres_delta': 0.0,
#    'Temperature_delta': 0.1666666666666714},
#   '第134號': {'Precp_delta': 0.3333333333333333,
#    'RH_delta': 2.0,
#    'StnPres_delta': 1.7333333333332348,
#    'Temperature_delta': -0.09999999999999787},
#   '第135號': {'Precp_delta': 0.3333333333333333,
#    'RH_delta': 2.0,
#    'StnPres_delta': 1.7333333333332348,
#    'Temperature_delta': -0.09999999999999787},
#   '第136號': {'Precp_delta': 0.3333333333333333,
#    'RH_delta': 2.0,
#    'StnPres_delta': 1.7333333333332348,
#    'Temperature_delta': -0.09999999999999787},
#   '第137號': {'Precp_delta': 0.3333333333333333,
#    'RH_delta': 2.0,
#    'StnPres_delta': 1.7333333333332348,
#    'Temperature_delta': -0.09999999999999787},
#   '第138號': {},
#   '第139號': {'Precp_delta': -12.466666666666669,
#    'RH_delta': -11.333333333333329,
#    'StnPres_delta': 1.3333333333333712,
#    'Temperature_delta': 2.9666666666666686},
#   '第140號': {},
#   '第141號': {},
#   '第142號': {'Precp_delta': nan,
#    'RH_delta': nan,
#    'StnPres_delta': nan,
#    'Temperature_delta': nan},
#   '第143號': {},
#   '第144號': {},
#   '第145號': {'Precp_delta': 5.866666666666667,
#    'RH_delta': -1.6666666666666714,
#    'StnPres_delta': 2.6333333333333258,
#    'Temperature_delta': -0.9000000000000021},
#   '第146號': {'Precp_delta': 0.0,
#    'RH_delta': -3.0,
#    'StnPres_delta': -0.7999999999999545,
#    'Temperature_delta': 0.56666666666667},
#   '第147號': {'Precp_delta': 17.46666666666667,
#    'RH_delta': 6.666666666666657,
#    'StnPres_delta': -1.5666666666664923,
#    'Temperature_delta': 0.2666666666666657},
#   '第148號': {},
#   '第149號': {},
#   '第150號': {},
#   '第151號': {'Precp_delta': 19.033333333333335,
#    'RH_delta': 4.666666666666657,
#    'StnPres_delta': -2.4666666666665833,
#    'Temperature_delta': -0.23333333333333428},
#   '第152號': {},
#   '第153號': {},
#   '第154號': {},
#   '第155號': {},
#   '第156號': {},
#   '第157號': {'Precp_delta': -0.43333333333333335,
#    'RH_delta': -9.666666666666657,
#    'StnPres_delta': 5.866666666666447,
#    'Temperature_delta': -1.999999999999993},
#   '第158號': {},
#   '第159號': {},
#   '第160號': {'Precp_delta': -0.3333333333333333,
#    'RH_delta': -4.333333333333329,
#    'StnPres_delta': 2.2000000000000455,
#    'Temperature_delta': -1.7666666666666657},
#   '第161號': {},
#   '第162號': {},
#   '第163號': {},
#   '第164號': {},
#   '第165號': {'Precp_delta': 1.0666666666666667,
#    'RH_delta': 19.999999999999993,
#    'StnPres_delta': 0.6000000000000227,
#    'Temperature_delta': 2.6666666666666714},
#   '第166號': {'Precp_delta': 13.033333333333339,
#    'RH_delta': 0.6666666666666572,
#    'StnPres_delta': 5.466666666666697,
#    'Temperature_delta': -6.633333333333335},
#   '第167號': {},
#   '第168號': {},
#   '第169號': {},
#   '第170號': {},
#   '第171號': {},
#   '第172號': {'Precp_delta': 3.0,
#    'RH_delta': 14.333333333333329,
#    'StnPres_delta': -5.933333333333394,
#    'Temperature_delta': 0.6333333333333364}},
#  '2012': {'第001號': {},
#   '第002號': {},
#   '第003號': {},
#   '第004號': {},
#   '第005號': {'Precp_delta': -0.5,
#    'RH_delta': -2.0,
#    'StnPres_delta': -0.7666666666667652,
#    'Temperature_delta': 4.033333333333337},
#   '第006號': {},
#   '第007號': {},
#   '第008號': {},
#   '第009號': {},
#   '第010號': {},
#   '第011號': {},
#   '第012號': {},
#   '第013號': {},
#   '第014號': {},
#   '第015號': {},
#   '第016號': {},
#   '第017號': {'Precp_delta': -2.6333333333333333,
#    'RH_delta': 0.0,
#    'StnPres_delta': 2.133333333333212,
#    'Temperature_delta': 0.33333333333333215},
#   '第018號': {},
#   '第019號': {'Precp_delta': 0.0,
#    'RH_delta': -0.6666666666666714,
#    'StnPres_delta': 2.233333333333235,
#    'Temperature_delta': -2.9333333333333336},
#   '第020號': {'Precp_delta': -27.0,
#    'RH_delta': -2.0,
#    'StnPres_delta': -1.599999999999909,
#    'Temperature_delta': 2.533333333333335},
#   '第021號': {},
#   '第022號': {},
#   '第023號': {},
#   '第024號': {'Precp_delta': -60.03333333333333,
#    'RH_delta': -5.0,
#    'StnPres_delta': -7.700000000000159,
#    'Temperature_delta': 4.0},
#   '第025號': {},
#   '第026號': {},
#   '第027號': {},
#   '第028號': {},
#   '第029號': {},
#   '第030號': {'Precp_delta': 0.0,
#    'RH_delta': -2.0,
#    'StnPres_delta': -4.0,
#    'Temperature_delta': 0.03333333333333499},
#   '第031號': {},
#   '第032號': {},
#   '第033號': {},
#   '第034號': {},
#   '第035號': {},
#   '第036號': {},
#   '第037號': {'Precp_delta': 0.3333333333333333,
#    'RH_delta': -10.666666666666671,
#    'StnPres_delta': 3.133333333333212,
#    'Temperature_delta': -2.2666666666666693},
#   '第038號': {'Precp_delta': 0.3333333333333333,
#    'RH_delta': -10.666666666666671,
#    'StnPres_delta': 3.133333333333212,
#    'Temperature_delta': -2.2666666666666693},
#   '第039號': {'Precp_delta': 0.3333333333333333,
#    'RH_delta': -10.666666666666671,
#    'StnPres_delta': 3.133333333333212,
#    'Temperature_delta': -2.2666666666666693},
#   '第040號': {},
#   '第041號': {},
#   '第042號': {},
#   '第043號': {},
#   '第044號': {},
#   '第045號': {'Precp_delta': 0.3333333333333333,
#    'RH_delta': -5.333333333333329,
#    'StnPres_delta': 7.133333333333212,
#    'Temperature_delta': -4.9999999999999964},
#   '第046號': {},
#   '第047號': {},
#   '第048號': {'Precp_delta': -0.2666666666666657,
#    'RH_delta': 2.666666666666657,
#    'StnPres_delta': 3.0333333333334167,
#    'Temperature_delta': -4.033333333333331},
#   '第049號': {'Precp_delta': 0.26666666666666666,
#    'RH_delta': -7.0,
#    'StnPres_delta': 2.233333333333462,
#    'Temperature_delta': -3.500000000000007},
#   '第050號': {'Precp_delta': 0.0,
#    'RH_delta': -11.0,
#    'StnPres_delta': 5.199999999999932,
#    'Temperature_delta': -2.1000000000000014},
#   '第051號': {},
#   '第052號': {},
#   '第053號': {},
#   '第054號': {},
#   '第055號': {},
#   '第056號': {},
#   '第057號': {},
#   '第058號': {},
#   '第059號': {'Precp_delta': 0.5,
#    'RH_delta': -2.3333333333333286,
#    'StnPres_delta': -6.299999999999841,
#    'Temperature_delta': 3.2333333333333307},
#   '第060號': {'Precp_delta': 0.0,
#    'RH_delta': 0.3333333333333286,
#    'StnPres_delta': -2.366666666666788,
#    'Temperature_delta': 0.7666666666666693},
#   '第061號': {},
#   '第062號': {},
#   '第063號': {},
#   '第064號': {},
#   '第065號': {},
#   '第066號': {'Precp_delta': -0.16666666666666666,
#    'RH_delta': 5.0,
#    'StnPres_delta': -0.9999999999998863,
#    'Temperature_delta': 2.0333333333333314},
#   '第067號': {},
#   '第068號': {'Precp_delta': 0.0,
#    'RH_delta': 7.0,
#    'StnPres_delta': -1.4333333333332803,
#    'Temperature_delta': -0.1999999999999993},
#   '第069號': {},
#   '第070號': {},
#   '第071號': {'Precp_delta': -1.0333333333333332,
#    'RH_delta': -4.333333333333343,
#    'StnPres_delta': 0.13333333333343944,
#    'Temperature_delta': 0.16666666666666785},
#   '第072號': {'Precp_delta': -1.0333333333333332,
#    'RH_delta': -4.333333333333343,
#    'StnPres_delta': 0.13333333333343944,
#    'Temperature_delta': 0.16666666666666785},
#   '第073號': {},
#   '第074號': {},
#   '第075號': {},
#   '第076號': {},
#   '第077號': {},
#   '第078號': {},
#   '第079號': {},
#   '第080號': {},
#   '第081號': {},
#   '第082號': {},
#   '第083號': {'Precp_delta': -15.7,
#    'RH_delta': -9.0,
#    'StnPres_delta': 1.433333333333394,
#    'Temperature_delta': 1.9666666666666686},
#   '第084號': {},
#   '第085號': {'Precp_delta': 44.53333333333333,
#    'RH_delta': 12.333333333333329,
#    'StnPres_delta': -1.5,
#    'Temperature_delta': -0.9999999999999964},
#   '第086號': {},
#   '第087號': {},
#   '第088號': {},
#   '第089號': {},
#   '第090號': {'Precp_delta': nan,
#    'RH_delta': nan,
#    'StnPres_delta': nan,
#    'Temperature_delta': nan},
#   '第091號': {'Precp_delta': nan,
#    'RH_delta': nan,
#    'StnPres_delta': nan,
#    'Temperature_delta': nan},
#   '第092號': {},
#   '第093號': {},
#   '第094號': {},
#   '第095號': {},
#   '第096號': {},
#   '第097號': {},
#   '第098號': {},
#   '第099號': {},
#   '第100號': {},
#   '第101號': {},
#   '第102號': {},
#   '第103號': {},
#   '第104號': {},
#   '第105號': {},
#   '第106號': {},
#   '第107號': {},
#   '第108號': {},
#   '第109號': {},
#   '第110號': {},
#   '第111號': {},
#   '第112號': {'Precp_delta': -16.266666666666673,
#    'RH_delta': -6.333333333333329,
#    'StnPres_delta': 3.0,
#    'Temperature_delta': 3.133333333333333},
#   '第113號': {},
#   '第114號': {},
#   '第115號': {},
#   '第116號': {},
#   '第117號': {},
#   '第118號': {},
#   '第119號': {},
#   '第120號': {},
#   '第121號': {},
#   '第122號': {},
#   '第123號': {},
#   '第124號': {},
#   '第125號': {},
#   '第126號': {},
#   '第127號': {},
#   '第128號': {},
#   '第129號': {},
#   '第130號': {},
#   '第131號': {},
#   '第132號': {},
#   '第133號': {},
#   '第134號': {},
#   '第135號': {'Precp_delta': 33.166666666666664,
#    'RH_delta': 7.0,
#    'StnPres_delta': 1.033333333333303,
#    'Temperature_delta': -1.1000000000000014},
#   '第136號': {},
#   '第137號': {},
#   '第138號': {},
#   '第139號': {},
#   '第140號': {},
#   '第141號': {},
#   '第142號': {},
#   '第143號': {'Precp_delta': 14.0,
#    'RH_delta': -1.3333333333333286,
#    'StnPres_delta': 1.6000000000001364,
#    'Temperature_delta': -0.33333333333333215},
#   '第144號': {},
#   '第145號': {},
#   '第146號': {},
#   '第147號': {},
#   '第148號': {},
#   '第149號': {'Precp_delta': 0.0,
#    'RH_delta': -7.000000000000007,
#    'StnPres_delta': -4.466666666666583,
#    'Temperature_delta': 0.7666666666666693},
#   '第150號': {'Precp_delta': 14.0,
#    'RH_delta': 11.0,
#    'StnPres_delta': -1.1333333333334394,
#    'Temperature_delta': -2.2666666666666693},
#   '第151號': {'Precp_delta': 7.133333333333334,
#    'RH_delta': 4.333333333333329,
#    'StnPres_delta': 2.7333333333333485,
#    'Temperature_delta': -1.3333333333333393},
#   '第152號': {},
#   '第153號': {'Precp_delta': nan,
#    'RH_delta': nan,
#    'StnPres_delta': nan,
#    'Temperature_delta': nan},
#   '第154號': {'Precp_delta': 4.333333333333333,
#    'RH_delta': 2.6666666666666714,
#    'StnPres_delta': 7.999999999999886,
#    'Temperature_delta': 0.26666666666666217},
#   '第155號': {},
#   '第156號': {},
#   '第157號': {},
#   '第158號': {},
#   '第159號': {},
#   '第160號': {},
#   '第161號': {},
#   '第162號': {},
#   '第163號': {},
#   '第164號': {},
#   '第165號': {},
#   '第166號': {},
#   '第167號': {'Precp_delta': 39.5,
#    'RH_delta': 11.666666666666671,
#    'StnPres_delta': -1.6666666666667425,
#    'Temperature_delta': -1.3666666666666636},
#   '第168號': {},
#   '第169號': {},
#   '第170號': {},
#   '第171號': {'Precp_delta': 6.133333333333333,
#    'RH_delta': 10.333333333333329,
#    'StnPres_delta': -0.29999999999984084,
#    'Temperature_delta': 0.23333333333333428},
#   '第172號': {},
#   '第173號': {},
#   '第174號': {},
#   '第175號': {'Precp_delta': 0.0,
#    'RH_delta': 14.0,
#    'StnPres_delta': 0.566666666666606,
#    'Temperature_delta': 1.2999999999999972},
#   '第176號': {},
#   '第177號': {'Precp_delta': 0.0,
#    'RH_delta': -3.3333333333333286,
#    'StnPres_delta': -2.7999999999999545,
#    'Temperature_delta': -0.6333333333333293},
#   '第178號': {'Precp_delta': 0.9333333333333331,
#    'RH_delta': 2.6666666666666714,
#    'StnPres_delta': -2.6000000000000227,
#    'Temperature_delta': -0.8333333333333321},
#   '第179號': {'Precp_delta': -19.633333333333336,
#    'RH_delta': -10.333333333333343,
#    'StnPres_delta': -1.066666666666947,
#    'Temperature_delta': -0.20000000000000284},
#   '第180號': {'Precp_delta': -3.0,
#    'RH_delta': 3.0,
#    'StnPres_delta': 0.9666666666668107,
#    'Temperature_delta': 1.5333333333333332},
#   '第181號': {'Precp_delta': 0.0,
#    'RH_delta': 17.66666666666667,
#    'StnPres_delta': 2.0000000000001137,
#    'Temperature_delta': -1.7000000000000002},
#   '第182號': {'Precp_delta': 0.0,
#    'RH_delta': 6.000000000000007,
#    'StnPres_delta': 1.2333333333334622,
#    'Temperature_delta': 0.8999999999999986},
#   '第183號': {},
#   '第184號': {'Precp_delta': 0.0,
#    'RH_delta': 3.0,
#    'StnPres_delta': 4.633333333333212,
#    'Temperature_delta': -0.40000000000000213},
#   '第185號': {'Precp_delta': 23.833333333333332,
#    'RH_delta': 14.666666666666671,
#    'StnPres_delta': -0.10000000000002274,
#    'Temperature_delta': 1.2333333333333343},
#   '第186號': {'Precp_delta': 0.0,
#    'RH_delta': 3.3333333333333286,
#    'StnPres_delta': -1.2666666666666515,
#    'Temperature_delta': 2.2333333333333343},
#   '第187號': {},
#   '第188號': {},
#   '第189號': {'Precp_delta': -0.2666666666666667,
#    'RH_delta': -2.3333333333333286,
#    'StnPres_delta': -0.8333333333333712,
#    'Temperature_delta': 0.9333333333333371},
#   '第190號': {},
#   '第191號': {},
#   '第192號': {},
#   '第193號': {},
#   '第194號': {},
#   '第195號': {},
#   '第196號': {},
#   '第197號': {},
#   '第198號': {},
#   '第199號': {},
#   '第200號': {},
#   '第201號': {},
#   '第202號': {},
#   '第203號': {},
#   '第204號': {},
#   '第205號': {},
#   '第206號': {},
#   '第207號': {},
#   '第208號': {'Precp_delta': 7.766666666666667,
#    'RH_delta': 2.333333333333343,
#    'StnPres_delta': 4.800000000000182,
#    'Temperature_delta': -5.266666666666666},
#   '第209號': {},
#   '第210號': {},
#   '第211號': {},
#   '第212號': {},
#   '第213號': {'Precp_delta': 4.266666666666667,
#    'RH_delta': 5.666666666666671,
#    'StnPres_delta': 0.599999999999909,
#    'Temperature_delta': -0.8000000000000043},
#   '第214號': {'Precp_delta': -2.3999999999999995,
#    'RH_delta': 4.666666666666671,
#    'StnPres_delta': 3.733333333333235,
#    'Temperature_delta': -1.9333333333333353}},
#  '2013': {'第001號': {},
#   '第002號': {},
#   '第003號': {},
#   '第004號': {},
#   '第005號': {},
#   '第006號': {},
#   '第007號': {},
#   '第008號': {'Precp_delta': 0.0,
#    'RH_delta': -6.0,
#    'StnPres_delta': 2.033333333333303,
#    'Temperature_delta': -0.2666666666666657},
#   '第009號': {'Precp_delta': -7.033333333333332,
#    'RH_delta': -13.333333333333336,
#    'StnPres_delta': 6.900000000000091,
#    'Temperature_delta': -2.3000000000000007},
#   '第010號': {},
#   '第011號': {'Precp_delta': -4.133333333333333,
#    'RH_delta': 11.0,
#    'StnPres_delta': -5.7333333333333485,
#    'Temperature_delta': 1.8666666666666636},
#   '第012號': {},
#   '第013號': {},
#   '第014號': {},
#   '第015號': {},
#   '第016號': {'Precp_delta': 58.499999999999986,
#    'RH_delta': 0.3333333333333428,
#    'StnPres_delta': 1.8999999999998636,
#    'Temperature_delta': -5.633333333333329},
#   '第017號': {},
#   '第018號': {},
#   '第019號': {},
#   '第020號': {'Precp_delta': 0.0,
#    'RH_delta': 0.0,
#    'StnPres_delta': 3.4999999999998863,
#    'Temperature_delta': -2.666666666666668},
#   '第021號': {'Precp_delta': 0.0,
#    'RH_delta': 4.0,
#    'StnPres_delta': 4.066666666666833,
#    'Temperature_delta': -3.366666666666667},
#   '第022號': {'Precp_delta': 0.0,
#    'RH_delta': -3.0,
#    'StnPres_delta': 2.866666666666447,
#    'Temperature_delta': -0.7666666666666693},
#   '第023號': {'Precp_delta': 2.5666666666666664,
#    'RH_delta': -4.333333333333343,
#    'StnPres_delta': 5.366666666666561,
#    'Temperature_delta': -0.5666666666666664},
#   '第024號': {'Precp_delta': 3.6666666666666665,
#    'RH_delta': 5.333333333333329,
#    'StnPres_delta': 3.4333333333332803,
#    'Temperature_delta': -0.3333333333333357},
#   '第025號': {'Precp_delta': 3.6666666666666665,
#    'RH_delta': 5.333333333333329,
#    'StnPres_delta': 3.4333333333332803,
#    'Temperature_delta': -0.3333333333333357},
#   '第026號': {},
#   '第027號': {},
#   '第028號': {},
#   '第029號': {},
#   '第030號': {},
#   '第031號': {},
#   '第032號': {},
#   '第033號': {},
#   '第034號': {},
#   '第035號': {},
#   '第036號': {},
#   '第037號': {},
#   '第038號': {'Precp_delta': -8.666666666666666,
#    'RH_delta': 1.0,
#    'StnPres_delta': -0.4999999999998863,
#    'Temperature_delta': 0.8000000000000007},
#   '第039號': {'Precp_delta': -0.3333333333333333,
#    'RH_delta': 5.0,
#    'StnPres_delta': 1.166666666666515,
#    'Temperature_delta': 0.06666666666666998},
#   '第040號': {'Precp_delta': 3.6999999999999993,
#    'RH_delta': 7.333333333333343,
#    'StnPres_delta': 2.300000000000068,
#    'Temperature_delta': -1.8666666666666636},
#   '第041號': {},
#   '第042號': {},
#   '第043號': {},
#   '第044號': {'Precp_delta': -13.3,
#    'RH_delta': 3.0,
#    'StnPres_delta': -0.16666666666662877,
#    'Temperature_delta': -0.8666666666666665},
#   '第045號': {},
#   '第046號': {'Precp_delta': -36.96666666666667,
#    'RH_delta': -9.333333333333343,
#    'StnPres_delta': 4.833333333333371,
#    'Temperature_delta': -2.5},
#   '第047號': {},
#   '第048號': {},
#   '第049號': {},
#   '第050號': {},
#   '第051號': {},
#   '第052號': {},
#   '第053號': {},
#   '第054號': {'Precp_delta': 0.3333333333333333,
#    'RH_delta': -2.0,
#    'StnPres_delta': 5.100000000000136,
#    'Temperature_delta': -1.5333333333333314},
#   '第055號': {'Precp_delta': -1.4333333333333331,
#    'RH_delta': -8.666666666666671,
#    'StnPres_delta': 4.366666666666788,
#    'Temperature_delta': -0.7333333333333343},
#   '第056號': {},
#   '第057號': {},
#   '第058號': {'Precp_delta': 2.2,
#    'RH_delta': 0.6666666666666714,
#    'StnPres_delta': -2.2999999999999545,
#    'Temperature_delta': 0.3666666666666636},
#   '第059號': {},
#   '第060號': {'Precp_delta': 40.2,
#    'RH_delta': 7.333333333333329,
#    'StnPres_delta': -0.8666666666667879,
#    'Temperature_delta': -1.2666666666666657},
#   '第061號': {},
#   '第062號': {},
#   '第063號': {},
#   '第064號': {},
#   '第065號': {},
#   '第066號': {},
#   '第067號': {},
#   '第068號': {},
#   '第069號': {},
#   '第070號': {},
#   '第071號': {},
#   '第072號': {'Precp_delta': -12.433333333333332,
#    'RH_delta': -11.333333333333329,
#    'StnPres_delta': -0.2333333333332348,
#    'Temperature_delta': 1.8333333333333357},
#   '第073號': {},
#   '第074號': {},
#   '第075號': {'Precp_delta': 5.666666666666667,
#    'RH_delta': 19.66666666666667,
#    'StnPres_delta': 1.8000000000000682,
#    'Temperature_delta': -0.8000000000000007},
#   '第076號': {'Precp_delta': 5.666666666666667,
#    'RH_delta': 19.66666666666667,
#    'StnPres_delta': 1.8000000000000682,
#    'Temperature_delta': -0.8000000000000007},
#   '第077號': {},
#   '第078號': {},
#   '第079號': {},
#   '第080號': {},
#   '第081號': {},
#   '第082號': {},
#   '第083號': {},
#   '第084號': {},
#   '第085號': {'Precp_delta': 1.2999999999999998,
#    'RH_delta': -1.3333333333333286,
#    'StnPres_delta': -0.6333333333333258,
#    'Temperature_delta': -0.1333333333333364},
#   '第086號': {},
#   '第087號': {},
#   '第088號': {},
#   '第089號': {},
#   '第090號': {},
#   '第091號': {},
#   '第092號': {'Precp_delta': 10.600000000000003,
#    'RH_delta': 3.0,
#    'StnPres_delta': 0.2333333333332348,
#    'Temperature_delta': -1.3333333333333357},
#   '第093號': {'Precp_delta': 0.0,
#    'RH_delta': -1.6666666666666714,
#    'StnPres_delta': -1.2666666666666515,
#    'Temperature_delta': 0.36666666666666714},
#   '第094號': {'Precp_delta': 0.0,
#    'RH_delta': -1.6666666666666714,
#    'StnPres_delta': -1.2666666666666515,
#    'Temperature_delta': 0.36666666666666714},
#   '第095號': {'Precp_delta': 0.0,
#    'RH_delta': -1.6666666666666714,
#    'StnPres_delta': -1.2666666666666515,
#    'Temperature_delta': 0.36666666666666714},
#   '第096號': {'Precp_delta': -2.5,
#    'RH_delta': -3.666666666666657,
#    'StnPres_delta': -0.966666666666697,
#    'Temperature_delta': 0.3666666666666636},
#   '第097號': {},
#   '第098號': {},
#   '第099號': {'Precp_delta': -116.16666666666667,
#    'RH_delta': -17.0,
#    'StnPres_delta': 6.166666666666629,
#    'Temperature_delta': 0.6333333333333329},
#   '第100號': {},
#   '第101號': {'Precp_delta': 189.83333333333334,
#    'RH_delta': 5.333333333333329,
#    'StnPres_delta': -4.066666666666833,
#    'Temperature_delta': -0.20000000000000284},
#   '第102號': {'Precp_delta': 189.83333333333334,
#    'RH_delta': 5.333333333333329,
#    'StnPres_delta': -4.066666666666833,
#    'Temperature_delta': -0.20000000000000284},
#   '第103號': {},
#   '第104號': {},
#   '第105號': {},
#   '第106號': {},
#   '第107號': {'Precp_delta': 24.633333333333333,
#    'RH_delta': 11.666666666666671,
#    'StnPres_delta': -3.6333333333333258,
#    'Temperature_delta': 0.4333333333333371},
#   '第108號': {'Precp_delta': 79.5,
#    'RH_delta': 19.33333333333333,
#    'StnPres_delta': -10.300000000000068,
#    'Temperature_delta': -1.100000000000005},
#   '第109號': {'Precp_delta': 53.5,
#    'RH_delta': 12.333333333333343,
#    'StnPres_delta': -5.466666666666697,
#    'Temperature_delta': -0.6666666666666679},
#   '第110號': {'Precp_delta': 0.0,
#    'RH_delta': -5.0,
#    'StnPres_delta': 1.333333333333485,
#    'Temperature_delta': -0.1333333333333364},
#   '第111號': {'Precp_delta': 0.0,
#    'RH_delta': -5.999999999999993,
#    'StnPres_delta': 0.36666666666678793,
#    'Temperature_delta': 1.7763568394002505e-15},
#   '第112號': {'Precp_delta': 0.0,
#    'RH_delta': -1.0,
#    'StnPres_delta': 1.8999999999999773,
#    'Temperature_delta': 0.3666666666666636},
#   '第113號': {'Precp_delta': -1.2666666666666666,
#    'RH_delta': -13.333333333333329,
#    'StnPres_delta': 2.033333333333303,
#    'Temperature_delta': -0.03333333333333499},
#   '第114號': {},
#   '第115號': {},
#   '第116號': {},
#   '第117號': {'Precp_delta': -18.0,
#    'RH_delta': -13.666666666666664,
#    'StnPres_delta': -3.733333333333235,
#    'Temperature_delta': -0.899999999999995},
#   '第118號': {},
#   '第119號': {},
#   '第120號': {'Precp_delta': 0.0,
#    'RH_delta': 7.0,
#    'StnPres_delta': 0.8333333333333712,
#    'Temperature_delta': 2.5},
#   '第121號': {},
#   '第122號': {},
#   '第123號': {},
#   '第124號': {},
#   '第125號': {},
#   '第126號': {},
#   '第127號': {},
#   '第128號': {},
#   '第129號': {},
#   '第130號': {},
#   '第131號': {},
#   '第132號': {},
#   '第133號': {},
#   '第134號': {},
#   '第135號': {},
#   '第136號': {},
#   '第137號': {},
#   '第138號': {},
#   '第139號': {},
#   '第140號': {},
#   '第141號': {},
#   '第142號': {},
#   '第143號': {'Precp_delta': 0.0,
#    'RH_delta': 0.3333333333333286,
#    'StnPres_delta': 0.10000000000013642,
#    'Temperature_delta': 0.5333333333333314},
#   '第144號': {},
#   '第145號': {},
#   '第146號': {},
#   '第147號': {},
#   '第148號': {},
#   '第149號': {},
#   '第150號': {},
#   '第151號': {'Precp_delta': -3.8666666666666667,
#    'RH_delta': -6.333333333333329,
#    'StnPres_delta': -1.3666666666666742,
#    'Temperature_delta': -3.566666666666667},
#   '第152號': {},
#   '第153號': {'Precp_delta': 15.633333333333333,
#    'RH_delta': 16.333333333333336,
#    'StnPres_delta': -4.6666666666667425,
#    'Temperature_delta': 3.799999999999997},
#   '第154號': {},
#   '第155號': {},
#   '第156號': {},
#   '第157號': {'Precp_delta': -0.8333333333333334,
#    'RH_delta': -11.666666666666671,
#    'StnPres_delta': 5.266666666666538,
#    'Temperature_delta': -3.333333333333332},
#   '第158號': {'Precp_delta': -1.6666666666666667,
#    'RH_delta': -4.0,
#    'StnPres_delta': 4.7333333333333485,
#    'Temperature_delta': -4.43333333333333},
#   '第159號': {},
#   '第160號': {'Precp_delta': 14.100000000000001,
#    'RH_delta': 9.333333333333343,
#    'StnPres_delta': -4.0,
#    'Temperature_delta': -1.9333333333333336},
#   '第161號': {},
#   '第162號': {},
#   '第163號': {'Precp_delta': 85.16666666666666,
#    'RH_delta': 8.666666666666657,
#    'StnPres_delta': -1.466666666666697,
#    'Temperature_delta': 2.0666666666666647},
#   '第164號': {'Precp_delta': -0.16666666666666666,
#    'RH_delta': -9.666666666666671,
#    'StnPres_delta': -3.533333333333303,
#    'Temperature_delta': -1.7333333333333325},
#   '第165號': {'Precp_delta': 2.566666666666667,
#    'RH_delta': 1.6666666666666714,
#    'StnPres_delta': -2.333333333333485,
#    'Temperature_delta': -2.8666666666666636},
#   '第166號': {'Precp_delta': -0.16666666666666666,
#    'RH_delta': -9.666666666666671,
#    'StnPres_delta': -3.533333333333303,
#    'Temperature_delta': -1.7333333333333325}},
#  '2014': {'第001號': {},
#   '第002號': {},
#   '第003號': {'Precp_delta': -0.16666666666666666,
#    'RH_delta': 7.0,
#    'StnPres_delta': 1.666666666666515,
#    'Temperature_delta': -4.233333333333331},
#   '第004號': {},
#   '第005號': {'Precp_delta': 2.466666666666667,
#    'RH_delta': 8.0,
#    'StnPres_delta': 0.7333333333332348,
#    'Temperature_delta': -0.4333333333333318},
#   '第006號': {'Precp_delta': 0.0,
#    'RH_delta': -3.6666666666666714,
#    'StnPres_delta': -0.16666666666662877,
#    'Temperature_delta': -1.0333333333333314},
#   '第007號': {},
#   '第008號': {},
#   '第009號': {},
#   '第010號': {},
#   '第011號': {},
#   '第012號': {'Precp_delta': 0.26666666666666666,
#    'RH_delta': 29.333333333333332,
#    'StnPres_delta': -3.9999999999998863,
#    'Temperature_delta': -5.333333333333333},
#   '第013號': {},
#   '第014號': {},
#   '第015號': {},
#   '第016號': {},
#   '第017號': {},
#   '第018號': {},
#   '第019號': {},
#   '第020號': {},
#   '第021號': {},
#   '第022號': {'Precp_delta': 22.099999999999998,
#    'RH_delta': 2.333333333333343,
#    'StnPres_delta': 5.43333333333328,
#    'Temperature_delta': -8.133333333333336},
#   '第023號': {},
#   '第024號': {'Precp_delta': -29.166666666666664,
#    'RH_delta': 0.6666666666666572,
#    'StnPres_delta': 3.0,
#    'Temperature_delta': 2.7333333333333334},
#   '第025號': {},
#   '第026號': {},
#   '第027號': {'Precp_delta': -1.6666666666666667,
#    'RH_delta': -4.666666666666671,
#    'StnPres_delta': 0.7000000000000455,
#    'Temperature_delta': 3.5666666666666664},
#   '第028號': {},
#   '第029號': {'Precp_delta': 3.0,
#    'RH_delta': 0.0,
#    'StnPres_delta': 0.06666666666660603,
#    'Temperature_delta': 0.9000000000000004},
#   '第030號': {},
#   '第031號': {'Precp_delta': 0.8333333333333334,
#    'RH_delta': -14.333333333333329,
#    'StnPres_delta': 5.033333333333303,
#    'Temperature_delta': -3.4666666666666686},
#   '第032號': {},
#   '第033號': {},
#   '第034號': {},
#   '第035號': {},
#   '第036號': {},
#   '第037號': {'Precp_delta': -0.09999999999999999,
#    'RH_delta': 0.6666666666666714,
#    'StnPres_delta': 2.8666666666666742,
#    'Temperature_delta': -1.7333333333333343},
#   '第038號': {},
#   '第039號': {'Precp_delta': -6.666666666666667,
#    'RH_delta': -13.333333333333343,
#    'StnPres_delta': 3.5,
#    'Temperature_delta': 0.5},
#   '第040號': {},
#   '第041號': {},
#   '第042號': {},
#   '第043號': {},
#   '第044號': {'Precp_delta': 0.0,
#    'RH_delta': -10.0,
#    'StnPres_delta': 3.4999999999998863,
#    'Temperature_delta': 0.6333333333333364},
#   '第045號': {'Precp_delta': 12.8,
#    'RH_delta': 14.333333333333329,
#    'StnPres_delta': -8.533333333333303,
#    'Temperature_delta': 4.966666666666669},
#   '第046號': {},
#   '第047號': {},
#   '第048號': {'Precp_delta': 1.6333333333333333,
#    'RH_delta': 6.333333333333343,
#    'StnPres_delta': -4.5,
#    'Temperature_delta': 1.9333333333333265},
#   '第049號': {},
#   '第050號': {'Precp_delta': 1.6333333333333333,
#    'RH_delta': 6.333333333333343,
#    'StnPres_delta': -4.5,
#    'Temperature_delta': 1.9333333333333265},
#   '第051號': {},
#   '第052號': {},
#   '第053號': {},
#   '第054號': {'Precp_delta': 4.8999999999999995,
#    'RH_delta': -2.6666666666666714,
#    'StnPres_delta': 1.2999999999999545,
#    'Temperature_delta': 0.9666666666666666},
#   '第055號': {},
#   '第056號': {},
#   '第057號': {},
#   '第058號': {},
#   '第059號': {'Precp_delta': 3.3000000000000003,
#    'RH_delta': 1.6666666666666714,
#    'StnPres_delta': 1.3999999999999773,
#    'Temperature_delta': -2.2666666666666693},
#   '第060號': {'Precp_delta': 0.0,
#    'RH_delta': -2.0,
#    'StnPres_delta': 0.06666666666660603,
#    'Temperature_delta': 0.09999999999999787},
#   '第061號': {},
#   '第062號': {},
#   '第063號': {},
#   '第064號': {},
#   '第065號': {},
#   '第066號': {'Precp_delta': 8.900000000000002,
#    'RH_delta': -9.0,
#    'StnPres_delta': -1.966666666666697,
#    'Temperature_delta': 3.333333333333332},
#   '第067號': {'Precp_delta': -1.1666666666666667,
#    'RH_delta': -1.6666666666666714,
#    'StnPres_delta': 2.0,
#    'Temperature_delta': 0.36666666666666714},
#   '第068號': {},
#   '第069號': {},
#   '第070號': {},
#   '第071號': {},
#   '第072號': {'Precp_delta': -2.1666666666666665,
#    'RH_delta': -2.0,
#    'StnPres_delta': -1.0666666666667197,
#    'Temperature_delta': 3.099999999999998},
#   '第073號': {},
#   '第074號': {},
#   '第075號': {},
#   '第076號': {},
#   '第077號': {},
#   '第078號': {'Precp_delta': 1.3333333333333335,
#    'RH_delta': -2.0,
#    'StnPres_delta': -2.933333333333394,
#    'Temperature_delta': 0.06666666666666643},
#   '第079號': {'Precp_delta': 1.9333333333333331,
#    'RH_delta': -8.333333333333329,
#    'StnPres_delta': -2.7999999999999545,
#    'Temperature_delta': 0.8333333333333321},
#   '第080號': {},
#   '第081號': {},
#   '第082號': {},
#   '第083號': {},
#   '第084號': {},
#   '第085號': {},
#   '第086號': {'Precp_delta': 1.1,
#    'RH_delta': -2.0,
#    'StnPres_delta': 2.2737367544323206e-13,
#    'Temperature_delta': 0.3000000000000007},
#   '第087號': {'Precp_delta': -4.333333333333333,
#    'RH_delta': -9.333333333333343,
#    'StnPres_delta': 0.0,
#    'Temperature_delta': 1.0333333333333314},
#   '第088號': {},
#   '第089號': {},
#   '第090號': {},
#   '第091號': {'Precp_delta': 9.0,
#    'RH_delta': 0.0,
#    'StnPres_delta': 0.0,
#    'Temperature_delta': 0.6666666666666679},
#   '第092號': {},
#   '第093號': {},
#   '第094號': {'Precp_delta': -0.06666666666666665,
#    'RH_delta': 3.0,
#    'StnPres_delta': -0.06666666666671972,
#    'Temperature_delta': -1.7333333333333343},
#   '第095號': {},
#   '第096號': {},
#   '第097號': {},
#   '第098號': {'Precp_delta': -44.0,
#    'RH_delta': -2.3333333333333286,
#    'StnPres_delta': 4.533333333333417,
#    'Temperature_delta': 0.9999999999999964},
#   '第099號': {'Precp_delta': 0.0,
#    'RH_delta': -4.333333333333343,
#    'StnPres_delta': -7.599999999999909,
#    'Temperature_delta': 0.7666666666666693},
#   '第100號': {},
#   '第101號': {},
#   '第102號': {},
#   '第103號': {'Precp_delta': -14.3,
#    'RH_delta': 6.0,
#    'StnPres_delta': 1.6000000000000227,
#    'Temperature_delta': -0.7000000000000028},
#   '第104號': {'Precp_delta': 1.5,
#    'RH_delta': -1.0,
#    'StnPres_delta': -1.2333333333333485,
#    'Temperature_delta': 0.13333333333333286},
#   '第105號': {'Precp_delta': 3.333333333333333,
#    'RH_delta': 6.0,
#    'StnPres_delta': -0.2333333333333485,
#    'Temperature_delta': -0.26666666666666217},
#   '第106號': {},
#   '第107號': {'Precp_delta': -4.0,
#    'RH_delta': -0.3333333333333428,
#    'StnPres_delta': 0.4666666666665833,
#    'Temperature_delta': -0.6333333333333364},
#   '第108號': {'Precp_delta': 6.366666666666667,
#    'RH_delta': 2.0,
#    'StnPres_delta': 1.5666666666667197,
#    'Temperature_delta': -0.5333333333333385},
#   '第109號': {'Precp_delta': 0.09999999999999999,
#    'RH_delta': -0.6666666666666714,
#    'StnPres_delta': -3.0,
#    'Temperature_delta': 0.3666666666666707},
#   '第110號': {},
#   '第111號': {'Precp_delta': -0.03333333333333334,
#    'RH_delta': -0.6666666666666572,
#    'StnPres_delta': 0.20000000000004547,
#    'Temperature_delta': 0.6333333333333364},
#   '第112號': {},
#   '第113號': {},
#   '第114號': {},
#   '第115號': {'Precp_delta': 2.5,
#    'RH_delta': 7.333333333333329,
#    'StnPres_delta': 4.366666666666788,
#    'Temperature_delta': -1.3000000000000043},
#   '第116號': {'Precp_delta': -25.166666666666668,
#    'RH_delta': -3.666666666666657,
#    'StnPres_delta': 3.6000000000001364,
#    'Temperature_delta': -0.4333333333333371},
#   '第117號': {},
#   '第118號': {},
#   '第119號': {},
#   '第120號': {},
#   '第121號': {'Precp_delta': 2.0,
#    'RH_delta': 10.000000000000007,
#    'StnPres_delta': -7.533333333333303,
#    'Temperature_delta': 1.8999999999999986},
#   '第122號': {},
#   '第123號': {},
#   '第124號': {},
#   '第125號': {'Precp_delta': 0.0,
#    'RH_delta': -4.333333333333343,
#    'StnPres_delta': 9.266666666666538,
#    'Temperature_delta': -2.1333333333333293},
#   '第126號': {'Precp_delta': 0.0,
#    'RH_delta': 7.666666666666671,
#    'StnPres_delta': 0.6666666666666288,
#    'Temperature_delta': -1.2333333333333378},
#   '第127號': {'Precp_delta': -2.0666666666666673,
#    'RH_delta': -7.333333333333343,
#    'StnPres_delta': 1.5,
#    'Temperature_delta': 1.5333333333333314},
#   '第128號': {'Precp_delta': -0.19999999999999998,
#    'RH_delta': -16.33333333333333,
#    'StnPres_delta': -1.566666666666606,
#    'Temperature_delta': 1.9000000000000021},
#   '第129號': {},
#   '第130號': {},
#   '第131號': {},
#   '第132號': {},
#   '第133號': {},
#   '第134號': {},
#   '第135號': {},
#   '第136號': {},
#   '第137號': {},
#   '第138號': {},
#   '第139號': {},
#   '第140號': {},
#   '第141號': {},
#   '第142號': {},
#   '第143號': {},
#   '第144號': {},
#   '第145號': {},
#   '第146號': {},
#   '第147號': {},
#   '第148號': {},
#   '第149號': {},
#   '第150號': {},
#   '第151號': {},
#   '第152號': {},
#   '第153號': {},
#   '第154號': {}},
#  '2015': {'第001號': {},
#   '第002號': {},
#   '第003號': {},
#   '第004號': {},
#   '第005號': {},
#   '第006號': {},
#   '第007號': {},
#   '第008號': {},
#   '第009號': {},
#   '第010號': {},
#   '第011號': {},
#   '第012號': {},
#   '第013號': {},
#   '第014號': {},
#   '第015號': {},
#   '第016號': {},
#   '第017號': {},
#   '第018號': {},
#   '第019號': {},
#   '第020號': {},
#   '第021號': {},
#   '第022號': {},
#   '第023號': {},
#   '第024號': {},
#   '第025號': {},
#   '第026號': {},
#   '第027號': {},
#   '第028號': {},
#   '第029號': {},
#   '第030號': {},
#   '第031號': {},
#   '第032號': {},
#   '第033號': {},
#   '第034號': {},
#   '第035號': {},
#   '第036號': {},
#   '第037號': {},
#   '第038號': {},
#   '第039號': {},
#   '第040號': {},
#   '第041號': {},
#   '第042號': {},
#   '第043號': {},
#   '第044號': {},
#   '第045號': {},
#   '第046號': {},
#   '第047號': {},
#   '第048號': {},
#   '第049號': {},
#   '第050號': {},
#   '第051號': {},
#   '第052號': {},
#   '第053號': {},
#   '第054號': {},
#   '第055號': {},
#   '第056號': {},
#   '第057號': {},
#   '第058號': {},
#   '第059號': {},
#   '第060號': {},
#   '第061號': {},
#   '第062號': {},
#   '第063號': {},
#   '第064號': {},
#   '第065號': {},
#   '第066號': {},
#   '第067號': {},
#   '第068號': {},
#   '第069號': {},
#   '第070號': {},
#   '第071號': {},
#   '第072號': {},
#   '第073號': {},
#   '第074號': {},
#   '第075號': {},
#   '第076號': {},
#   '第077號': {},
#   '第078號': {},
#   '第079號': {},
#   '第080號': {},
#   '第081號': {},
#   '第082號': {},
#   '第083號': {},
#   '第084號': {},
#   '第085號': {},
#   '第086號': {},
#   '第087號': {},
#   '第088號': {},
#   '第089號': {},
#   '第090號': {},
#   '第091號': {},
#   '第092號': {},
#   '第093號': {},
#   '第094號': {},
#   '第095號': {},
#   '第096號': {},
#   '第097號': {},
#   '第098號': {},
#   '第099號': {},
#   '第100號': {}},
#  '2016': {'第001號': {},
#   '第002號': {},
#   '第003號': {},
#   '第004號': {},
#   '第005號': {},
#   '第006號': {},
#   '第007號': {},
#   '第008號': {},
#   '第009號': {},
#   '第010號': {},
#   '第011號': {},
#   '第012號': {},
#   '第013號': {},
#   '第014號': {},
#   '第015號': {},
#   '第016號': {},
#   '第017號': {},
#   '第018號': {},
#   '第019號': {},
#   '第020號': {},
#   '第021號': {},
#   '第022號': {},
#   '第023號': {},
#   '第024號': {},
#   '第025號': {},
#   '第026號': {},
#   '第027號': {},
#   '第028號': {},
#   '第029號': {},
#   '第030號': {},
#   '第031號': {},
#   '第032號': {},
#   '第033號': {},
#   '第034號': {},
#   '第035號': {},
#   '第036號': {},
#   '第037號': {},
#   '第038號': {},
#   '第039號': {},
#   '第040號': {},
#   '第041號': {},
#   '第042號': {},
#   '第043號': {},
#   '第044號': {},
#   '第045號': {},
#   '第046號': {},
#   '第047號': {},
#   '第048號': {},
#   '第049號': {},
#   '第050號': {},
#   '第051號': {},
#   '第052號': {},
#   '第053號': {},
#   '第054號': {},
#   '第055號': {},
#   '第056號': {},
#   '第057號': {},
#   '第058號': {},
#   '第059號': {},
#   '第060號': {},
#   '第061號': {},
#   '第062號': {},
#   '第063號': {},
#   '第064號': {},
#   '第065號': {},
#   '第066號': {},
#   '第067號': {},
#   '第068號': {},
#   '第069號': {},
#   '第070號': {},
#   '第071號': {},
#   '第072號': {},
#   '第073號': {},
#   '第074號': {},
#   '第075號': {},
#   '第076號': {},
#   '第077號': {},
#   '第078號': {},
#   '第079號': {},
#   '第080號': {},
#   '第081號': {},
#   '第082號': {},
#   '第083號': {},
#   '第084號': {},
#   '第085號': {},
#   '第086號': {},
#   '第087號': {},
#   '第088號': {},
#   '第089號': {},
#   '第090號': {},
#   '第091號': {},
#   '第092號': {},
#   '第093號': {},
#   '第094號': {},
#   '第095號': {},
#   '第096號': {},
#   '第097號': {},
#   '第098號': {},
#   '第099號': {},
#   '第100號': {},
#   '第101號': {},
#   '第102號': {},
#   '第103號': {},
#   '第104號': {},
#   '第105號': {},
#   '第106號': {},
#   '第107號': {},
#   '第108號': {},
#   '第109號': {},
#   '第110號': {},
#   '第111號': {},
#   '第112號': {}},
#  '2017': {'第001號': {},
#   '第002號': {},
#   '第003號': {},
#   '第004號': {},
#   '第005號': {},
#   '第006號': {},
#   '第007號': {},
#   '第008號': {},
#   '第009號': {},
#   '第010號': {},
#   '第011號': {},
#   '第012號': {},
#   '第013號': {},
#   '第014號': {},
#   '第015號': {},
#   '第016號': {},
#   '第017號': {},
#   '第018號': {},
#   '第019號': {},
#   '第020號': {},
#   '第021號': {},
#   '第022號': {},
#   '第023號': {},
#   '第024號': {},
#   '第025號': {},
#   '第026號': {},
#   '第027號': {},
#   '第028號': {},
#   '第029號': {},
#   '第030號': {},
#   '第031號': {},
#   '第032號': {},
#   '第033號': {},
#   '第034號': {},
#   '第035號': {},
#   '第036號': {},
#   '第037號': {},
#   '第038號': {},
#   '第039號': {},
#   '第040號': {},
#   '第041號': {},
#   '第042號': {},
#   '第043號': {},
#   '第044號': {},
#   '第045號': {},
#   '第046號': {},
#   '第047號': {},
#   '第048號': {},
#   '第049號': {},
#   '第050號': {},
#   '第051號': {},
#   '第052號': {},
#   '第053號': {},
#   '第054號': {},
#   '第055號': {},
#   '第056號': {},
#   '第057號': {},
#   '第058號': {},
#   '第059號': {},
#   '第060號': {}}}

# %%
count = 0
count_change = 0
for year in deltaDict.keys():
    for num in deltaDict[year].keys():
        temp = deltaDict[year][num]
        if bool(temp): # is not empty
            count += 1
            count_OverGate = 0
            for dataType in needDataList[1:]:
                if deltaDict[year][num][dataType+"_delta"] > gateDict[dataType+"_gate"]:
                    count_OverGate += 1
            if count_OverGate > 3:
                count_change += 1
print("共",count,"可用資料，有", count_change, "筆成立")
# Out:
# 190 0

# %%
persent_high = 0.8
persent_low = 0.2
persent_count = count_change/count
if persent_count > persent_high:
    print("流言成立")
elif persent_count < persent_low:
    print("流言破解")    
else:
    print("流言待考究")
